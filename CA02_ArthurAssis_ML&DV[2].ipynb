# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Introduction and Business Understanding

# %%
df = pd.read_csv('DatafinitiElectronicsProductData.csv')

# %%
df.head()
# Out:
#                      id       asins      brand  \
# 0  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 1  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 2  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 3  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 4  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
#
#                                           categories colors  \
# 0  Electronics,Computers,Computer Accessories,Key...  Black
# 1  Electronics,Computers,Computer Accessories,Key...  Black
# 2  Electronics,Computers,Computer Accessories,Key...  Black
# 3  Electronics,Computers,Computer Accessories,Key...  Black
# 4  Electronics,Computers,Computer Accessories,Key...  Black
#
#               dateAdded           dateUpdated                   dimension  \
# 0  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 1  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 2  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 3  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 4  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
#
#             ean                                          imageURLs  ...  \
# 0  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 1  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 2  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 3  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 4  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
#
#   reviews.doRecommend reviews.numHelpful reviews.rating  \
# 0                True                0.0            5.0
# 1                True                0.0            4.0
# 2                True                0.0            4.0
# 3                True                0.0            5.0
# 4                True                0.0            5.0
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/4562009/review...
# 1  http://reviews.bestbuy.com/3545/4562009/review...
# 2  http://reviews.bestbuy.com/3545/4562009/review...
# 3  http://reviews.bestbuy.com/3545/4562009/review...
# 4  http://reviews.bestbuy.com/3545/4562009/review...
#
#                                         reviews.text  \
# 0  This keyboard is very easy to type on, but the...
# 1  It's thin and light. I can type pretty easily ...
# 2  I love the new design the keys are spaced well...
# 3  Attached easily and firmly. Has a nice feel. A...
# 4  Our original keyboard was okay, but did not ha...
#
#                  reviews.title reviews.username  \
# 0  Love the fingerprint reader             JNH1
# 1                         Nice             Appa
# 2                          New             Kman
# 3                Nice keyboard        UpstateNY
# 4             Nice improvement        Glickster
#
#                                           sourceURLs           upc      weight
# 0  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 1  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 2  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 3  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 4  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
#
# [5 rows x 27 columns]

# %%
df.iloc[:,10:14].head()
# Out:
#                                                 keys manufacturer  \
# 0  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 1  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 2  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 3  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 4  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
#
#   manufacturerNumber                                               name
# 0          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 1          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 2          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 3          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 4          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...

# %%
df['reviews.username'].nunique()
# Out:
# 6493

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7299 entries, 0 to 7298
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   7299 non-null   object
#  1   asins                7299 non-null   object
#  2   brand                7299 non-null   object
#  3   categories           7299 non-null   object
#  4   colors               5280 non-null   object
#  5   dateAdded            7299 non-null   object
#  6   dateUpdated          7299 non-null   object
#  7   dimension            6090 non-null   object
#  8   ean                  2951 non-null   float64
#  9   imageURLs            7299 non-null   object
#  10  keys                 7299 non-null   object
#  11  manufacturer         4632 non-null   object
#  12  manufacturerNumber   7299 non-null   object
#  13  name                 7299 non-null   object
#  14  primaryCategories    7299 non-null   object
#  15  reviews.date         7238 non-null   object
#  16  reviews.dateSeen     7299 non-null   object
#  17  reviews.doRecommend  5908 non-null   object
#  18  reviews.numHelpful   5813 non-null   float64
#  19  reviews.rating       7135 non-null   float64
#  20  reviews.sourceURLs   7299 non-null   object
#  21  reviews.text         7294 non-null   object
#  22  reviews.title        7295 non-null   object
#  23  reviews.username     7299 non-null   object
#  24  sourceURLs           7299 non-null   object
#  25  upc                  7299 non-null   float64
#  26  weight               7299 non-null   object
# dtypes: float64(4), object(23)
# memory usage: 1.5+ MB

# %%
#https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions/data?select=interactions_validation.csv
df_recipes = pd.read_csv('/Users/arthurassis/Documents/CCT - Data Analytics for Business/Machine Learning/Semester 2/CA02-MachineLearning:DataVisualisation-Semester 2/archive/RAW_recipes.csv')

# %% [markdown]
# # Building a content based recommendation system

# %%
df.head()
# Out:
#                      id       asins      brand  \
# 0  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 1  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 2  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 3  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 4  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
#
#                                           categories colors  \
# 0  Electronics,Computers,Computer Accessories,Key...  Black
# 1  Electronics,Computers,Computer Accessories,Key...  Black
# 2  Electronics,Computers,Computer Accessories,Key...  Black
# 3  Electronics,Computers,Computer Accessories,Key...  Black
# 4  Electronics,Computers,Computer Accessories,Key...  Black
#
#               dateAdded           dateUpdated                   dimension  \
# 0  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 1  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 2  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 3  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 4  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
#
#             ean                                          imageURLs  ...  \
# 0  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 1  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 2  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 3  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
# 4  8.900000e+11  https://i5.walmartimages.com/asr/2a41f6f0-844e...  ...
#
#   reviews.doRecommend reviews.numHelpful reviews.rating  \
# 0                True                0.0            5.0
# 1                True                0.0            4.0
# 2                True                0.0            4.0
# 3                True                0.0            5.0
# 4                True                0.0            5.0
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/4562009/review...
# 1  http://reviews.bestbuy.com/3545/4562009/review...
# 2  http://reviews.bestbuy.com/3545/4562009/review...
# 3  http://reviews.bestbuy.com/3545/4562009/review...
# 4  http://reviews.bestbuy.com/3545/4562009/review...
#
#                                         reviews.text  \
# 0  This keyboard is very easy to type on, but the...
# 1  It's thin and light. I can type pretty easily ...
# 2  I love the new design the keys are spaced well...
# 3  Attached easily and firmly. Has a nice feel. A...
# 4  Our original keyboard was okay, but did not ha...
#
#                  reviews.title reviews.username  \
# 0  Love the fingerprint reader             JNH1
# 1                         Nice             Appa
# 2                          New             Kman
# 3                Nice keyboard        UpstateNY
# 4             Nice improvement        Glickster
#
#                                           sourceURLs           upc      weight
# 0  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 1  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 2  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 3  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
# 4  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11  1.1 pounds
#
# [5 rows x 27 columns]

# %%
df.iloc[:,10:18].head()
# Out:
#                                                 keys manufacturer  \
# 0  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 1  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 2  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 3  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
# 4  microsoftsurfacepro4typecoverwithfingerprintid...    Microsoft
#
#   manufacturerNumber                                               name  \
# 0          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 1          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 2          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 3          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
# 4          RH7-00001  Microsoft Surface Pro 4 Type Cover with Finger...
#
#   primaryCategories              reviews.date  \
# 0       Electronics  2015-12-04T00:00:00.000Z
# 1       Electronics  2015-12-04T00:00:00.000Z
# 2       Electronics  2015-12-04T00:00:00.000Z
# 3       Electronics  2015-12-01T00:00:00.000Z
# 4       Electronics  2015-11-28T00:00:00.000Z
#
#                                     reviews.dateSeen reviews.doRecommend
# 0  2017-09-03T00:00:00Z,2017-08-27T00:00:00Z,2017...                True
# 1  2017-09-03T00:00:00Z,2017-08-27T00:00:00Z,2017...                True
# 2  2017-09-03T00:00:00Z,2017-08-27T00:00:00Z,2017...                True
# 3  2017-09-03T00:00:00Z,2017-08-27T00:00:00Z,2017...                True
# 4  2017-09-03T00:00:00Z,2017-08-27T00:00:00Z,2017...                True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7299 entries, 0 to 7298
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   7299 non-null   object
#  1   asins                7299 non-null   object
#  2   brand                7299 non-null   object
#  3   categories           7299 non-null   object
#  4   colors               5280 non-null   object
#  5   dateAdded            7299 non-null   object
#  6   dateUpdated          7299 non-null   object
#  7   dimension            6090 non-null   object
#  8   ean                  2951 non-null   float64
#  9   imageURLs            7299 non-null   object
#  10  keys                 7299 non-null   object
#  11  manufacturer         4632 non-null   object
#  12  manufacturerNumber   7299 non-null   object
#  13  name                 7299 non-null   object
#  14  primaryCategories    7299 non-null   object
#  15  reviews.date         7238 non-null   object
#  16  reviews.dateSeen     7299 non-null   object
#  17  reviews.doRecommend  5908 non-null   object
#  18  reviews.numHelpful   5813 non-null   float64
#  19  reviews.rating       7135 non-null   float64
#  20  reviews.sourceURLs   7299 non-null   object
#  21  reviews.text         7294 non-null   object
#  22  reviews.title        7295 non-null   object
#  23  reviews.username     7299 non-null   object
#  24  sourceURLs           7299 non-null   object
#  25  upc                  7299 non-null   float64
#  26  weight               7299 non-null   object
# dtypes: float64(4), object(23)
# memory usage: 1.5+ MB

# %%
df['reviews.rating'].dropna(inplace = True)

# %%
rating = df.groupby(by = 'name')['reviews.rating'].mean()

# %%
rating
# Out:
# name
# 2TB Red 5400 rpm SATA III 3.5 Internal NAS HDD                                                                                       4.796296
# AW6500 All-Weather Outdoor Speaker (White, Single)                                                                                   4.851852
# Acoustimass 6 Series V Home Theater Speaker System (Black)                                                                           4.600000
# Air-Fi Runaway AF32 Stereo Bluetooth Wireless Headphones with Hidden Microphone (White)                                              4.412903
# Alpine                                                                                                                               4.263158
# Alpine - 6-1/2" 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black                                                   4.526923
# Bowers & Wilkins P7 Wired Over Ear Headphones                                                                                        4.766355
# Boytone - 2500W 2.1-Ch. Home Theater System - Black Diamond                                                                          4.453333
# CRX-322 CD Receiver                                                                                                                  5.000000
# Clarity - Super-Loud Phone Ringer - White                                                                                            4.909091
# Corsair CMSA8GX3M2A1066C7 Apple 8 GB Dual Channel Kit DDR3 1066 (PC3 8500) 204-Pin DDR3 Laptop SO-DIMM Memory 1.5V                   4.798246
# DreamWave - Tremor Portable Bluetooth Speaker - Green,Black                                                                          3.500000
# Everest Elite 700 Around-Ear Wireless Headphones (White)                                                                             4.263305
# Flipside 300 Backpack (Black)                                                                                                        4.625954
# House of Marley EM-DH003-PS TTR Noise-Cancelling Over-Ear Headphones (Black)                                                         5.000000
# JBL - 6" x 8" 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black                                                     4.762887
# JVC KD-X320BTS Apple iPod and Android Digital Media Receiver with Bluetooth                                                          4.604478
# Kicker 41IK5BT2V2 Amphitheater High-Performance Audio System with Bluetooth, Black                                                   5.000000
# Lenovo - AC Adapter for Select Lenovo Yoga Laptops - Black                                                                           4.535714
# Logitech 915-000224  Harmony Ultimate One 15-Device Universal Infrared Remote with Customizable Touch Screen Control - Black         3.945761
# Logitech G403 Wireless Gaming Mouse with High Performance Gaming Sensor                                                              4.852273
# Microsoft Surface Pro 4 Type Cover with Fingerprint ID                                                                               4.606061
# Midland Weather Alert Radio, 1.0 CT                                                                                                  4.659091
# Motorola Wi-Fi Pet Video Camera                                                                                                      3.850000
# NS-IW480CWH In-Ceiling 8 Natural Sound Three-Way Speaker System (Pair)                                                               4.800000
# NS-SP1800BL 5.1-Channel Home Theater System (Black)                                                                                  4.614458
# Nighthawk AC1900 Dual-Band Wi-Fi USB Adapter                                                                                         4.570470
# PNY Anarchy 16GB Kit (2x8GB) DDR4 2400MHz (PC4-19200) CL15 Desktop Memory (BLUE) - MD16GK2D4240015AB                                 4.549738
# Power Acoustik - Gothic Series 10" Dual-Voice-Coil 2-Ohm Subwoofer - Black                                                           4.750000
# Prime Three-Way Center Channel Speaker (Premium Black Ash)                                                                           5.000000
# Round LCD/Projector Ceiling Plate - Black                                                                                            4.250000
# SAMSUNG 40'' Class FHD (1080P) Smart LED TV (UN40M5300)                                                                              4.397059
# SRS-ZR7 Wireless Speaker                                                                                                             4.333333
# Samsung Universal 3100mAh Portable External Battery Charger - White                                                                  4.550000
# Sanus VLF410B1 10-Inch Super Slim Full-Motion Mount for 37 - 84 Inches TV's                                                          4.456790
# SiriusXM SXEZR1V1 XM Onyx EZR Satellite Radio Receiver with Vehicle Kit                                                              4.277778
# Slingbox M2                                                                                                                          4.301170
# Sony LBT-GPX555 Mini-System with Bluetooth and NFC                                                                                   4.476510
# Sony MEXM100BT 160W RMS Marine CD Receiver with Bluetooth (Black) and SiriusXM Ready                                                 4.115942
# Sony Mini Digital Video Cassettes - DVC - 1 Hour                                                                                     4.830000
# Sony SRSHG1/BLK Hi-Res Wireless Speaker- Charcoal black                                                                              4.297753
# Sony SRSXB30/BLK XB30 Portable Wireless Speaker with Bluetooth                                                                       4.637317
# The Rebel BT On-Ear Wireless Bluetooth Headphones (Black)                                                                            4.333333
# Toshiba - 3TB Internal Serial ATA III Hard Drive for Desktops                                                                        4.529412
# Toshiba Micro Component Speaker System: Wireless Bluetooth Speaker Sound System with FM                                              5.000000
# Travel RockStar 3-in-1 2A USB and Dual-Outlet Wall Charger with Internal 3000mAh Battery Pack                                        3.875000
# Ultimate Ears MEGABLAST Portable Wi-Fi/Bluetooth Speaker with hands-free Amazon Alexa voice control (waterproof) - Graphite Black    4.290000
# Verizon MiFi 6620L Jetpack 4G LTE Mobile Hotspot (Verizon Wireless)                                                                  4.435714
# XPS 8920 Tower Desktop Computer                                                                                                      4.500000
# iHome Rechargeable Splash Proof Stereo Bluetooth Speaker - Black (IBT33BC)                                                           4.298701
# Name: reviews.rating, dtype: float64

# %%
products_count = df.groupby(by = 'name').size()

# %%
products_count.sort_values(ascending=False)
# Out:
# name
# Logitech 915-000224  Harmony Ultimate One 15-Device Universal Infrared Remote with Customizable Touch Screen Control - Black         1604
# Microsoft Surface Pro 4 Type Cover with Fingerprint ID                                                                                507
# Sony SRSXB30/BLK XB30 Portable Wireless Speaker with Bluetooth                                                                        477
# Everest Elite 700 Around-Ear Wireless Headphones (White)                                                                              357
# Slingbox M2                                                                                                                           342
# SAMSUNG 40'' Class FHD (1080P) Smart LED TV (UN40M5300)                                                                               340
# Alpine - 6-1/2" 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black                                                    270
# PNY Anarchy 16GB Kit (2x8GB) DDR4 2400MHz (PC4-19200) CL15 Desktop Memory (BLUE) - MD16GK2D4240015AB                                  191
# Sony SRSHG1/BLK Hi-Res Wireless Speaker- Charcoal black                                                                               178
# Sanus VLF410B1 10-Inch Super Slim Full-Motion Mount for 37 - 84 Inches TV's                                                           162
# Air-Fi Runaway AF32 Stereo Bluetooth Wireless Headphones with Hidden Microphone (White)                                               160
# Sony LBT-GPX555 Mini-System with Bluetooth and NFC                                                                                    157
# iHome Rechargeable Splash Proof Stereo Bluetooth Speaker - Black (IBT33BC)                                                            154
# Nighthawk AC1900 Dual-Band Wi-Fi USB Adapter                                                                                          149
# Verizon MiFi 6620L Jetpack 4G LTE Mobile Hotspot (Verizon Wireless)                                                                   148
# Flipside 300 Backpack (Black)                                                                                                         143
# JVC KD-X320BTS Apple iPod and Android Digital Media Receiver with Bluetooth                                                           142
# Alpine                                                                                                                                127
# AW6500 All-Weather Outdoor Speaker (White, Single)                                                                                    123
# XPS 8920 Tower Desktop Computer                                                                                                       116
# Corsair CMSA8GX3M2A1066C7 Apple 8 GB Dual Channel Kit DDR3 1066 (PC3 8500) 204-Pin DDR3 Laptop SO-DIMM Memory 1.5V                    114
# Bowers & Wilkins P7 Wired Over Ear Headphones                                                                                         107
# NS-SP1800BL 5.1-Channel Home Theater System (Black)                                                                                   101
# Ultimate Ears MEGABLAST Portable Wi-Fi/Bluetooth Speaker with hands-free Amazon Alexa voice control (waterproof) - Graphite Black     100
# Sony Mini Digital Video Cassettes - DVC - 1 Hour                                                                                      100
# JBL - 6" x 8" 2-Way Coaxial Car Speakers with Polypropylene Cones (Pair) - Black                                                       97
# SiriusXM SXEZR1V1 XM Onyx EZR Satellite Radio Receiver with Vehicle Kit                                                                90
# Logitech G403 Wireless Gaming Mouse with High Performance Gaming Sensor                                                                88
# Samsung Universal 3100mAh Portable External Battery Charger - White                                                                    86
# Boytone - 2500W 2.1-Ch. Home Theater System - Black Diamond                                                                            83
# Sony MEXM100BT 160W RMS Marine CD Receiver with Bluetooth (Black) and SiriusXM Ready                                                   69
# SRS-ZR7 Wireless Speaker                                                                                                               66
# 2TB Red 5400 rpm SATA III 3.5 Internal NAS HDD                                                                                         54
# Motorola Wi-Fi Pet Video Camera                                                                                                        48
# Midland Weather Alert Radio, 1.0 CT                                                                                                    44
# Travel RockStar 3-in-1 2A USB and Dual-Outlet Wall Charger with Internal 3000mAh Battery Pack                                          40
# Lenovo - AC Adapter for Select Lenovo Yoga Laptops - Black                                                                             39
# NS-IW480CWH In-Ceiling 8 Natural Sound Three-Way Speaker System (Pair)                                                                 38
# Acoustimass 6 Series V Home Theater Speaker System (Black)                                                                             25
# Toshiba - 3TB Internal Serial ATA III Hard Drive for Desktops                                                                          17
# Clarity - Super-Loud Phone Ringer - White                                                                                              11
# CRX-322 CD Receiver                                                                                                                    11
# Toshiba Micro Component Speaker System: Wireless Bluetooth Speaker Sound System with FM                                                 6
# Round LCD/Projector Ceiling Plate - Black                                                                                               4
# Power Acoustik - Gothic Series 10" Dual-Voice-Coil 2-Ohm Subwoofer - Black                                                              4
# Kicker 41IK5BT2V2 Amphitheater High-Performance Audio System with Bluetooth, Black                                                      3
# The Rebel BT On-Ear Wireless Bluetooth Headphones (Black)                                                                               3
# DreamWave - Tremor Portable Bluetooth Speaker - Green,Black                                                                             2
# Prime Three-Way Center Channel Speaker (Premium Black Ash)                                                                              1
# House of Marley EM-DH003-PS TTR Noise-Cancelling Over-Ear Headphones (Black)                                                            1
# dtype: int64

# %%
products_count = products_count.reset_index()

# %%
df_recipes = pd.merge(df_recipes, recipe_rating, on='recipe_id',
                      how='left')

# %%
df_recipes = pd.merge(df_recipes, recipe_count, on='recipe_id', how = 'left')

# %%
df_recipes.rename(columns = {0:'reviews_count'}, inplace = True)

# %%
df_recipes.head()
# Out:
#                                          name  recipe_id  minutes  \
# 0  arriba   baked winter squash mexican style     137739       55
# 1            a bit different  breakfast pizza      31490       30
# 2                   all in the kitchen  chili     112140      130
# 3                          alouette  potatoes      59389       45
# 4          amish  tomato ketchup  for canning      44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  rating  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7     5.0
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6     3.5
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13     4.0
# 3  ['spreadable cheese with garlic and herbs', 'n...             11     4.5
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8     5.0
#
#    reviews_count
# 0              3
# 1              4
# 2              1
# 3              2
# 4              1

# %%
most_relevant_reviews = 40000

# %%
df_recipes = df_recipes.nlargest(most_relevant_reviews, 'reviews_count').reset_index()

# %%
df_recipes.to_csv('Filtered_recipes.csv', index=False)

# %%
df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           40000 non-null  int64
#  1   name            40000 non-null  object
#  2   recipe_id       40000 non-null  int64
#  3   minutes         40000 non-null  int64
#  4   contributor_id  40000 non-null  int64
#  5   submitted       40000 non-null  object
#  6   tags            40000 non-null  object
#  7   nutrition       40000 non-null  object
#  8   n_steps         40000 non-null  int64
#  9   steps           40000 non-null  object
#  10  description     39131 non-null  object
#  11  ingredients     40000 non-null  object
#  12  n_ingredients   40000 non-null  int64
#  13  rating          40000 non-null  float64
#  14  reviews_count   40000 non-null  int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 4.6+ MB

# %%
rating_average = df_recipes['rating'].mean()
print(rating_average)
# Out:
# 4.450785045245674

# %%
df_recipes.drop(columns = 'submitted', inplace = True)

# %%
df_recipes.description.head(10)
# Out:
# 0    you'll never need another banana bread recipe ...
# 1    amazing flavor, and so simple! no salt needed ...
# 2    i love this crock-pot chicken recipe for two r...
# 3    n'awlin's style of chicken with an updated alf...
# 4    this is one of (if not) the best banana cake i...
# 5    absolutely delicious meatloaf and sauce! those...
# 6    my kids will give up a steak dinner for this s...
# 7    these are absolutely the chewiest, moistest, f...
# 8    cooking the meatballs in simmering pasta sauce...
# 9    we have a japanese girl, tomoko, living with u...
# Name: description, dtype: object

# %%
print(df_recipes.tags[0])
# Out:
# ['time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'north-american', 'breads', 'fruit', 'american', 'oven', 'dietary', 'quick-breads', 'equipment', '4-hours-or-less']

# %%
features = ['tags','ingredients']

# %%
# Parse the stringified features into their corresponding python objects
from ast import literal_eval

for feature in features:
    df_recipes[feature] = df_recipes[feature].apply(literal_eval)

# %%
def get_first_five(x):
    return x[:5]

# %%
df_recipes['tags'] = df_recipes['tags'].apply(get_first_five)

# %%
#for feature in features:     
#    df_recipes[features] = df_recipes[features].apply(get_first_five)

# %%
print(df_recipes['tags'][3])
# Out:
# ['30-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine']

# %%
print(df_recipes['ingredients'][3])
# Out:
# ['boneless skinless chicken breast halves', 'linguine', 'cajun seasoning', 'butter', 'green onion', 'heavy whipping cream', 'sun-dried tomatoes', 'salt', 'dried basil', 'ground black pepper', 'garlic powder', 'parmesan cheese']

# %%
df_recipes[['tags', 'nutrition', 'ingredients']].head()
# Out:
#                                                 tags  \
# 0  [time-to-make, course, main-ingredient, cuisin...
# 1  [weeknight, time-to-make, course, main-ingredi...
# 2  [time-to-make, course, main-ingredient, prepar...
# 3  [30-minutes-or-less, time-to-make, course, mai...
# 4  [weeknight, time-to-make, course, main-ingredi...
#
#                                       nutrition  \
# 0    [272.8, 16.0, 97.0, 14.0, 7.0, 31.0, 14.0]
# 1     [295.2, 14.0, 0.0, 15.0, 99.0, 19.0, 0.0]
# 2   [679.2, 53.0, 39.0, 38.0, 91.0, 75.0, 16.0]
# 3  [719.1, 63.0, 12.0, 34.0, 78.0, 120.0, 15.0]
# 4  [503.5, 31.0, 222.0, 15.0, 11.0, 61.0, 25.0]
#
#                                          ingredients
# 0  [butter, granulated sugar, eggs, bananas, all-...
# 1  [beef roast, brown gravy mix, dried italian sa...
# 2  [boneless chicken breasts, black beans, corn, ...
# 3  [boneless skinless chicken breast halves, ling...
# 4  [bananas, lemon juice, flour, baking soda, sal...

# %%
def create_soup(x):
    return ' '.join(x['tags']) + ' ' + x['nutrition'] + ' ' + ' '.join(x['ingredients'])

# %%
# Create a new soup feature
df_recipes['soup'] = df_recipes.apply(create_soup, axis=1)

# %%
df_recipes['soup'].head()
# Out:
# 0    time-to-make course main-ingredient cuisine pr...
# 1    weeknight time-to-make course main-ingredient ...
# 2    time-to-make course main-ingredient preparatio...
# 3    30-minutes-or-less time-to-make course main-in...
# 4    weeknight time-to-make course main-ingredient ...
# Name: soup, dtype: object

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df_recipes['soup'])

# %%
count_matrix.shape
# Out:
# (40000, 5497)

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix[:40000], count_matrix[:40000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 # Compute the Cosine Similarity matrix based on the count_matrix
#       2 from sklearn.metrics.pairwise import cosine_similarity
# ----> 4 cosine_sim = cosine_similarity(count_matrix[:40000], count_matrix[:40000])
#
# NameError: name 'count_matrix' is not defined

# %%
# Reset index of your main DataFrame and construct reverse mapping as before
indices = pd.Series(df_recipes.index, index=df_recipes['name'])

# %%
print(indices[:25])
# Out:
# name
# best banana bread                                              0
# to die for crock pot roast                                     1
# crock pot chicken with black beans   cream cheese              2
# creamy cajun chicken pasta                                     3
# best ever banana cake with cream cheese frosting               4
# yes  virginia there is a great meatloaf                        5
# jo mama s world famous spaghetti                               6
# whatever floats your boat  brownies                            7
# kittencal s italian melt in your mouth meatballs               8
# japanese mum s chicken                                         9
# creamy burrito casserole                                      10
# kittencal s moist cheddar garlic oven fried chicken breast    11
# banana banana bread                                           12
# oven fried chicken chimichangas                               13
# fannie farmer s classic baked macaroni   cheese               14
# southern buttermilk biscuits                                  15
# the best easy beef and broccoli stir fry                      16
# delicious chicken pot pie                                     17
# simply sour cream chicken enchiladas                          18
# crock pot whole chicken                                       19
# my family s favorite sloppy joes  pizza joes                  20
# panera s cream cheese potato soup                             21
# soft snickerdoodle cookies                                    22
# beth s melt in your mouth barbecue ribs  oven                 23
# pete s scratch pancakes                                       24
# dtype: int64

# %%
indices['banana banana bread']
# Out:
# 12

# %%
cosine_sim[12]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 cosine_sim[12]
#
# NameError: name 'cosine_sim' is not defined

# %%
cosine_sim.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 cosine_sim.shape
#
# NameError: name 'cosine_sim' is not defined

# %%
# Function that takes in Recipe name as input and outputs most similar recipes
def get_recommendations(name, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[name]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the recipes based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar recipes
    sim_scores = sim_scores[1:11]

    # Get the recipes id
    recipes_id = [i[0] for i in sim_scores]

    # Return the top 10 most similar recipes
    return df_recipes['name'].iloc[recipes_id]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Function that takes in Recipe name as input and outputs most similar recipes
# ----> 2 def get_recommendations(name, cosine_sim=cosine_sim):
#       3     # Get the index of the movie that matches the title
#       4     idx = indices[name]
#       6     # Get the pairwsie similarity scores of all movies with that movie
#
# NameError: name 'cosine_sim' is not defined

# %%
get_recommendations('japanese mum s chicken')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 get_recommendations('japanese mum s chicken')
#
# NameError: name 'get_recommendations' is not defined

# %% [markdown]
# # Creating a Collaborative Filtering

# %% [markdown]
# Refer to:
# https://saturncloud.io/blog/how-to-select-rows-from-a-dataframe-based-on-list-values-in-a-column-in-pandas/#:~:text=To%20select%20rows%20from%20a%20DataFrame%20based%20on%20a%20list,to%20select%20the%20desired%20rows.
# and
# https://sparkbyexamples.com/pandas/conver-pandas-column-to-list/#

# %%
valid_recipes_id = df_recipes['recipe_id'].values.tolist()

# %%
valid_recipes_id
# Out:
# [2886,
#  27208,
#  89204,
#  39087,
#  67256,
#  54257,
#  22782,
#  32204,
#  69173,
#  68955,
#  33919,
#  82102,
#  25885,
#  28148,
#  135350,
#  26110,
#  99476,
#  10744,
#  129926,
#  33671,
#  63689,
#  150863,
#  97496,
#  107786,
#  5170,
#  32614,
#  95222,
#  38298,
#  77397,
#  131018,
#  29679,
#  87782,
#  4627,
#  73166,
#  50719,
#  66121,
#  141983,
#  37336,
#  28768,
#  43509,
#  60350,
#  76864,
#  150384,
#  2496,
#  27520,
#  89207,
#  31750,
#  9272,
#  92095,
#  78814,
#  132263,
#  76930,
#  53914,
#  15411,
#  8701,
#  73825,
#  90674,
#  15242,
#  32844,
#  80156,
#  261889,
#  200296,
#  63828,
#  31128,
#  71373,
#  70165,
#  33921,
#  15865,
#  26370,
#  77585,
#  34382,
#  9836,
#  33489,
#  27144,
#  114392,
#  27210,
#  66596,
#  106251,
#  52035,
#  43023,
#  63786,
#  69630,
#  205890,
#  103215,
#  26217,
#  82925,
#  128956,
#  46922,
#  95569,
#  349246,
#  15072,
#  47195,
#  16531,
#  8782,
#  108364,
#  3470,
#  107997,
#  22176,
#  48760,
#  46877,
#  133751,
#  53878,
#  65340,
#  145038,
#  63071,
#  221743,
#  56103,
#  1356,
#  87085,
#  31717,
#  48635,
#  8739,
#  29598,
#  66703,
#  4957,
#  52488,
#  80470,
#  34499,
#  49387,
#  54351,
#  222188,
#  83524,
#  26257,
#  20616,
#  19424,
#  87075,
#  80536,
#  35805,
#  51537,
#  40497,
#  37413,
#  50144,
#  155186,
#  106627,
#  21761,
#  64446,
#  31516,
#  110506,
#  105670,
#  43072,
#  121490,
#  108775,
#  52253,
#  66241,
#  29544,
#  108522,
#  79944,
#  42169,
#  75302,
#  25730,
#  82486,
#  129345,
#  45940,
#  20155,
#  35988,
#  302120,
#  178370,
#  30366,
#  13285,
#  42780,
#  44888,
#  102274,
#  32147,
#  29884,
#  108231,
#  79563,
#  57130,
#  30081,
#  80413,
#  42094,
#  76491,
#  112683,
#  87925,
#  10125,
#  55768,
#  21882,
#  104086,
#  101104,
#  185342,
#  18914,
#  14979,
#  56694,
#  24672,
#  185445,
#  78579,
#  66575,
#  17126,
#  78194,
#  145064,
#  99709,
#  136589,
#  46780,
#  102617,
#  486261,
#  177558,
#  52272,
#  52892,
#  74629,
#  116849,
#  13269,
#  11345,
#  339453,
#  74730,
#  53508,
#  34688,
#  26849,
#  34881,
#  100727,
#  101954,
#  13546,
#  27733,
#  26306,
#  21363,
#  183081,
#  59635,
#  89751,
#  105594,
#  12591,
#  49200,
#  87748,
#  111777,
#  49737,
#  486496,
#  13982,
#  83203,
#  42603,
#  44232,
#  42071,
#  31562,
#  8603,
#  12522,
#  129598,
#  53198,
#  35393,
#  11107,
#  108248,
#  108105,
#  135272,
#  32618,
#  18816,
#  84516,
#  83561,
#  33170,
#  50684,
#  199579,
#  155021,
#  8972,
#  28165,
#  749,
#  80118,
#  76616,
#  118761,
#  293243,
#  137530,
#  25723,
#  155018,
#  48532,
#  98867,
#  152441,
#  132546,
#  139518,
#  98724,
#  110683,
#  262140,
#  53301,
#  64138,
#  8596,
#  46262,
#  3180,
#  69089,
#  14499,
#  51997,
#  9494,
#  38041,
#  57919,
#  71557,
#  107072,
#  45069,
#  33665,
#  46501,
#  38641,
#  486641,
#  26947,
#  31342,
#  36984,
#  107281,
#  31371,
#  28943,
#  68159,
#  50338,
#  95068,
#  92016,
#  16371,
#  98415,
#  19724,
#  74048,
#  79606,
#  28011,
#  30946,
#  29493,
#  109685,
#  137575,
#  256914,
#  145312,
#  16887,
#  101041,
#  51209,
#  38966,
#  32607,
#  29935,
#  294196,
#  146427,
#  47111,
#  136923,
#  92096,
#  29301,
#  126623,
#  82023,
#  125633,
#  5478,
#  348802,
#  99156,
#  55673,
#  28648,
#  29329,
#  38953,
#  16884,
#  251220,
#  215414,
#  43908,
#  103403,
#  51140,
#  138173,
#  27968,
#  56366,
#  117317,
#  35775,
#  141789,
#  128566,
#  20048,
#  115110,
#  69407,
#  137725,
#  3603,
#  162379,
#  29002,
#  9327,
#  108651,
#  257276,
#  71360,
#  66409,
#  8579,
#  13949,
#  51104,
#  30358,
#  115432,
#  59224,
#  14911,
#  95086,
#  67781,
#  19023,
#  113299,
#  49534,
#  208583,
#  19678,
#  187362,
#  27221,
#  33105,
#  109264,
#  50767,
#  4178,
#  16213,
#  11763,
#  9954,
#  73469,
#  59336,
#  107190,
#  96988,
#  79595,
#  17987,
#  16705,
#  98869,
#  32731,
#  32503,
#  78088,
#  96886,
#  18185,
#  153642,
#  71109,
#  79308,
#  96475,
#  96514,
#  82945,
#  211485,
#  13619,
#  87864,
#  214051,
#  126611,
#  111734,
#  18888,
#  88804,
#  13307,
#  17186,
#  137364,
#  40983,
#  28377,
#  607,
#  30951,
#  57679,
#  64015,
#  14756,
#  22539,
#  88939,
#  259573,
#  37638,
#  24476,
#  77854,
#  69983,
#  28091,
#  31235,
#  105726,
#  25625,
#  110047,
#  24088,
#  8650,
#  107544,
#  125399,
#  46739,
#  81211,
#  55796,
#  35889,
#  158832,
#  84324,
#  50722,
#  115153,
#  301754,
#  24139,
#  133513,
#  17566,
#  34011,
#  19710,
#  339905,
#  73927,
#  49230,
#  29210,
#  32042,
#  11923,
#  83464,
#  72308,
#  14106,
#  131639,
#  100526,
#  92021,
#  9004,
#  23108,
#  46072,
#  76470,
#  28667,
#  17394,
#  70646,
#  99103,
#  128952,
#  48401,
#  23939,
#  294620,
#  52206,
#  119373,
#  44833,
#  45006,
#  71933,
#  73062,
#  41705,
#  57772,
#  51550,
#  106715,
#  100408,
#  411501,
#  73488,
#  13745,
#  192346,
#  102073,
#  117532,
#  104628,
#  20431,
#  31804,
#  88486,
#  97340,
#  30965,
#  180306,
#  33869,
#  303245,
#  92072,
#  52366,
#  84474,
#  181106,
#  28758,
#  93886,
#  113914,
#  15489,
#  41541,
#  107868,
#  73033,
#  15846,
#  12365,
#  18693,
#  3595,
#  30165,
#  19859,
#  9370,
#  117565,
#  216350,
#  94532,
#  88753,
#  10481,
#  132052,
#  67733,
#  107570,
#  84612,
#  14684,
#  9240,
#  17586,
#  86623,
#  60235,
#  17722,
#  1005,
#  91644,
#  70522,
#  78938,
#  96347,
#  71739,
#  39618,
#  39900,
#  90975,
#  26526,
#  26111,
#  149257,
#  497021,
#  102335,
#  63712,
#  111797,
#  25806,
#  34335,
#  37374,
#  11028,
#  50979,
#  47391,
#  86307,
#  183399,
#  77861,
#  81902,
#  14357,
#  118242,
#  74301,
#  224947,
#  139664,
#  50022,
#  74275,
#  177017,
#  26339,
#  13320,
#  86868,
#  139499,
#  110078,
#  24799,
#  32142,
#  12316,
#  18651,
#  22169,
#  104975,
#  90765,
#  26845,
#  136292,
#  135814,
#  107142,
#  42292,
#  129040,
#  87420,
#  238069,
#  76003,
#  137262,
#  75061,
#  20184,
#  29100,
#  26205,
#  37548,
#  137253,
#  83475,
#  216237,
#  100513,
#  59636,
#  133448,
#  38137,
#  52104,
#  380988,
#  50453,
#  26766,
#  11217,
#  106618,
#  83624,
#  140878,
#  74086,
#  150898,
#  42976,
#  145256,
#  219251,
#  151177,
#  78897,
#  108524,
#  102631,
#  68063,
#  89164,
#  38846,
#  54715,
#  14569,
#  98447,
#  17181,
#  59363,
#  99564,
#  74982,
#  132765,
#  47326,
#  93946,
#  169500,
#  96154,
#  46267,
#  90502,
#  28662,
#  91720,
#  16273,
#  58823,
#  94031,
#  443758,
#  76043,
#  73362,
#  21597,
#  32973,
#  169764,
#  84987,
#  66947,
#  81845,
#  41156,
#  8794,
#  110846,
#  25775,
#  155959,
#  114558,
#  97439,
#  50342,
#  55514,
#  8969,
#  75737,
#  15194,
#  26210,
#  154388,
#  176016,
#  32734,
#  13707,
#  169790,
#  62480,
#  26230,
#  48957,
#  20099,
#  67405,
#  89177,
#  114575,
#  63244,
#  9054,
#  117026,
#  140486,
#  30484,
#  63138,
#  238994,
#  449452,
#  32756,
#  49172,
#  52999,
#  147497,
#  11266,
#  110548,
#  96111,
#  121498,
#  215370,
#  98636,
#  95311,
#  135930,
#  14325,
#  36970,
#  18387,
#  121897,
#  916,
#  73754,
#  59965,
#  67930,
#  116882,
#  106611,
#  84247,
#  144837,
#  55936,
#  32522,
#  23480,
#  244592,
#  65641,
#  92647,
#  57872,
#  48356,
#  15286,
#  155442,
#  144439,
#  181181,
#  30018,
#  41701,
#  60382,
#  28603,
#  37437,
#  69240,
#  198707,
#  58976,
#  81968,
#  24952,
#  106499,
#  372087,
#  29251,
#  84504,
#  73274,
#  104248,
#  26420,
#  3745,
#  50385,
#  20643,
#  31811,
#  287618,
#  12134,
#  118010,
#  150987,
#  135585,
#  199636,
#  67426,
#  81853,
#  54677,
#  4573,
#  5368,
#  28026,
#  101101,
#  19253,
#  210757,
#  59289,
#  30812,
#  100798,
#  128746,
#  99272,
#  61610,
#  110071,
#  118373,
#  31314,
#  37625,
#  295649,
#  46461,
#  150473,
#  81419,
#  29413,
#  66976,
#  5031,
#  35185,
#  52757,
#  113817,
#  5247,
#  22349,
#  63446,
#  123588,
#  34753,
#  148007,
#  89932,
#  17227,
#  4075,
#  13214,
#  93223,
#  44133,
#  128679,
#  266248,
#  45609,
#  41384,
#  340621,
#  60560,
#  22164,
#  25999,
#  53876,
#  26451,
#  17977,
#  103152,
#  86353,
#  80435,
#  59772,
#  49181,
#  123107,
#  68861,
#  11642,
#  81047,
#  367414,
#  105080,
#  65266,
#  69372,
#  166030,
#  26820,
#  70654,
#  26557,
#  67570,
#  28927,
#  165254,
#  57591,
#  24306,
#  99843,
#  76198,
#  25757,
#  62058,
#  116814,
#  27931,
#  69191,
#  11808,
#  112889,
#  88880,
#  99918,
#  178865,
#  40106,
#  360528,
#  88453,
#  474520,
#  145573,
#  116236,
#  20287,
#  30745,
#  59311,
#  45005,
#  24618,
#  8432,
#  98370,
#  84104,
#  74279,
#  148921,
#  59829,
#  37139,
#  77666,
#  350894,
#  78953,
#  97428,
#  57505,
#  89503,
#  57629,
#  71967,
#  26773,
#  33914,
#  54259,
#  8554,
#  38746,
#  8424,
#  232433,
#  23687,
#  21304,
#  49591,
#  12619,
#  162864,
#  17962,
#  26337,
#  110604,
#  32833,
#  2708,
#  71344,
#  51199,
#  63501,
#  29155,
#  155369,
#  50732,
#  12877,
#  83207,
#  90086,
#  31078,
#  76294,
#  343698,
#  31607,
#  66294,
#  109283,
#  116173,
#  97573,
#  153075,
#  24019,
#  36784,
#  64149,
#  65643,
#  98774,
#  9782,
#  107235,
#  58428,
#  167202,
#  501408,
#  132916,
#  474987,
#  64356,
#  16902,
#  11919,
#  14187,
#  5483,
#  16399,
#  24576,
#  495271,
#  60085,
#  161324,
#  8845,
#  17251,
#  87689,
#  90822,
#  81048,
#  88350,
#  56846,
#  313521,
#  57062,
#  50772,
#  161334,
#  52500,
#  132261,
#  97831,
#  74251,
#  8060,
#  4861,
#  113983,
#  57299,
#  56453,
#  36847,
#  12360,
#  29704,
#  42564,
#  114514,
#  118140,
#  95220,
#  52064,
#  158671,
#  169916,
#  20624,
#  41992,
#  1985,
#  241139,
#  100005,
#  8595,
#  18458,
#  29175,
#  14906,
#  39369,
#  38432,
#  33645,
#  25745,
#  44278,
#  114907,
#  100761,
#  31167,
#  4417,
#  18872,
#  12832,
#  56652,
#  90000,
#  118821,
#  142464,
#  8619,
#  462563,
#  347607,
#  69063,
#  53133,
#  166118,
#  104150,
#  150739,
#  46798,
#  77497,
#  32880,
#  21768,
#  12199,
#  21320,
#  31799,
#  10840,
#  36797,
#  23232,
#  860,
#  202891,
#  84764,
#  26932,
#  25094,
#  108447,
#  38088,
#  162765,
#  126673,
#  117194,
#  187731,
#  18947,
#  22274,
#  51257,
#  63860,
#  16687,
#  239398,
#  59469,
#  162873,
#  26168,
#  4332,
#  71876,
#  24712,
#  ...]

# %%
mask = df_users['recipe_id'].isin(valid_recipes_id)

# %%
df_validusers = df_users[mask]

# %%
df_validusers
# Out:
#             user_id  recipe_id        date  rating  \
# 8             76535     134728  2005-09-02       4
# 9            273745     134728  2005-12-22       5
# 10           353911     134728  2006-09-26       5
# 11           190375     134728  2007-03-09       5
# 12           468945     134728  2008-02-20       0
# ...             ...        ...         ...     ...
# 1132356      199020      82303  2013-03-18       5
# 1132357     1122988      82303  2014-07-08       5
# 1132358  2000137415      82303  2015-04-13       1
# 1132359  2001898209      82303  2018-07-05       5
# 1132360  2002357020      82303  2018-12-05       5
#
#                                                     review
# 8                                               Very good!
# 9                                   Better than the real!!
# 10       Absolutely AWESOME! I was speechless when I tr...
# 11       These taste absolutely wonderful!!  My son-in-...
# 12       Made my own buttermilk w/ vinegar and milk.  U...
# ...                                                    ...
# 1132356  5 stars for taste! I had a hard time getting m...
# 1132357  This was amazingly delicious!  The only change...
# 1132358  I&#039;ve improvised sauces that turned out be...
# 1132359  This is the best and easiest hot fudge ever. I...
# 1132360  Delicious quick thick chocolate sauce with ing...
#
# [740700 rows x 5 columns]

# %%
df_validusers.drop(columns = 'date', inplace = True)
# Out:
# /var/folders/pn/wtyvdcd51cx9_tq1wmxkf7gc0000gn/T/ipykernel_8370/320351805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_validusers.drop(columns = 'date', inplace = True)

# %%
users_count = df_validusers.groupby(by = 'user_id').size().reset_index()

# %%
users_count.rename(columns = {0:'count'}, inplace = True)

# %%
most_common_users = 10000

# %%
common_users = users_count.nlargest(most_common_users, 'count').reset_index()

# %%
common_users_id = common_users['user_id'].values.tolist()

# %%
df_sampleusers = df_validusers[df_validusers['user_id'].isin(common_users_id)]

# %%
df_sampleusers
# Out:
#          user_id  recipe_id  rating  \
# 8          76535     134728       4
# 12        468945     134728       0
# 13        255338     134728       5
# 20        202555     225241       5
# 21        353579     225241       5
# ...          ...        ...     ...
# 1132322   482933     290157       5
# 1132354   143592      82303       5
# 1132355   140132      82303       5
# 1132356   199020      82303       5
# 1132357  1122988      82303       5
#
#                                                     review
# 8                                               Very good!
# 12       Made my own buttermilk w/ vinegar and milk.  U...
# 13       First time using liquid smoke in a recipe. Mad...
# 20       My husband has just found out that he had to c...
# 21       Very good, made with ingredients I usually hav...
# ...                                                    ...
# 1132322  Perfect combination of flavors!  I used this f...
# 1132354  I will never buy hot fudge again. This is so q...
# 1132355  This is fabulous.  I made it for our dessert t...
# 1132356  5 stars for taste! I had a hard time getting m...
# 1132357  This was amazingly delicious!  The only change...
#
# [487266 rows x 4 columns]

# %%
Mean = df_sampleusers.groupby(by="user_id",as_index=False)['rating'].mean()

# %%
rating_avg = pd.merge(df_sampleusers,Mean,on='user_id')

# %%
rating_avg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487266 entries, 0 to 487265
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    487266 non-null  int64
#  1   recipe_id  487266 non-null  int64
#  2   rating_x   487266 non-null  int64
#  3   review     487263 non-null  object
#  4   rating_y   487266 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 18.6+ MB

# %%
rating_avg.head()
# Out:
#    user_id  recipe_id  rating_x  \
# 0    76535     134728         4
# 1    76535      79378         5
# 2    76535      96091         2
# 3    76535      36984         4
# 4    76535      70965         3
#
#                                               review  rating_y
# 0                                         Very good!  4.158537
# 1  Frosty and delicious! I added more sugar to mi...  4.158537
# 2                               This was just so-so.  4.158537
# 3                                         Very good!  4.158537
# 4  These were gooey and wonderful--and a perfect ...  4.158537

# %%
rating_avg.user_id.nunique()
# Out:
# 10000

# %%
rating_avg.recipe_id.nunique()
# Out:
# 39670

# %%
rating_avg['adg_rating']=rating_avg['rating_x']-rating_avg['rating_y']

# %%
check = pd.pivot_table(rating_avg,values='rating_x',index='user_id',columns='recipe_id')
check
# Out:
# recipe_id   40      49      58      62      66      91      93      112     \
# user_id
# 1533           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1535           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1634           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1676           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1792           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2001513060     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2001524408     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2001574271     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2001704911     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2001836906     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# recipe_id   142     143     ...  524958  524960  528131  530004  530478  \
# user_id                     ...
# 1533           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1535           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1634           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1676           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1792           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2001513060     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2001524408     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2001574271     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2001704911     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2001836906     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
# recipe_id   531172  532740  534900  536119  536678
# user_id
# 1533           NaN     NaN     NaN     NaN     NaN
# 1535           NaN     NaN     NaN     NaN     NaN
# 1634           NaN     NaN     NaN     NaN     NaN
# 1676           NaN     NaN     NaN     NaN     NaN
# 1792           NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...
# 2001513060     NaN     NaN     NaN     NaN     NaN
# 2001524408     NaN     NaN     NaN     NaN     NaN
# 2001574271     NaN     NaN     NaN     NaN     NaN
# 2001704911     NaN     NaN     NaN     NaN     NaN
# 2001836906     NaN     NaN     NaN     NaN     NaN
#
# [10000 rows x 39670 columns]

# %%
final = pd.pivot_table(rating_avg,values='adg_rating',index='user_id',columns='recipe_id')
final.head()
# Out:
# recipe_id  40      49      58      62      66      91      93      112     \
# user_id
# 1533          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1535          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1634          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1676          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1792          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# recipe_id  142     143     ...  524958  524960  528131  530004  530478  \
# user_id                    ...
# 1533          NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1535          NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1634          NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1676          NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1792          NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
# recipe_id  531172  532740  534900  536119  536678
# user_id
# 1533          NaN     NaN     NaN     NaN     NaN
# 1535          NaN     NaN     NaN     NaN     NaN
# 1634          NaN     NaN     NaN     NaN     NaN
# 1676          NaN     NaN     NaN     NaN     NaN
# 1792          NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 39670 columns]

# %%
# Replacing NaN by Recipe Average
final_recipe = final.fillna(final.mean(axis=0))

# Replacing NaN by user Average
final_user = final.apply(lambda row: row.fillna(row.mean()), axis=1)

# %%
final_recipe.head()
# Out:
# recipe_id    40        49        58        62        66        91      \
# user_id
# 1533       0.169093  0.291155 -0.344436  0.062471  0.353991  0.247057
# 1535       0.169093  0.291155 -0.344436  0.062471  0.353991  0.247057
# 1634       0.169093  0.291155 -0.344436  0.062471  0.353991  0.247057
# 1676       0.169093  0.291155 -0.344436  0.062471  0.353991  0.247057
# 1792       0.169093  0.291155 -0.344436  0.062471  0.353991  0.247057
#
# recipe_id    93        112       142       143     ...    524958    524960  \
# user_id                                            ...
# 1533      -0.148495 -0.949875 -0.246348 -0.125016  ...  0.885281  1.048121
# 1535      -0.148495 -0.949875 -0.246348 -0.125016  ...  0.885281  1.048121
# 1634      -0.148495 -0.949875 -0.246348 -0.125016  ...  0.885281  1.048121
# 1676      -0.148495 -0.949875 -0.246348 -0.125016  ...  0.885281  1.048121
# 1792      -0.148495 -0.949875 -0.246348 -0.125016  ...  0.885281  1.048121
#
# recipe_id  528131    530004    530478    531172    532740    534900    536119  \
# user_id
# 1533         -1.5  0.090909  0.137931 -0.944444  0.208592  1.169811  0.165356
# 1535         -1.5  0.090909  0.137931 -0.944444  0.208592  1.169811  0.165356
# 1634         -1.5  0.090909  0.137931 -0.944444  0.208592  1.169811  0.165356
# 1676         -1.5  0.090909  0.137931 -0.944444  0.208592  1.169811  0.165356
# 1792         -1.5  0.090909  0.137931 -0.944444  0.208592  1.169811  0.165356
#
# recipe_id    536678
# user_id
# 1533       0.115399
# 1535       0.115399
# 1634       0.115399
# 1676       0.115399
# 1792       0.115399
#
# [5 rows x 39670 columns]

# %%
final_user.head()
# Out:
# recipe_id        40            49            58            62      \
# user_id
# 1533       2.478637e-16  2.478637e-16  2.478637e-16  2.478637e-16
# 1535      -2.173745e-16 -2.173745e-16 -2.173745e-16 -2.173745e-16
# 1634      -1.837611e-16 -1.837611e-16 -1.837611e-16 -1.837611e-16
# 1676       4.099285e-16  4.099285e-16  4.099285e-16  4.099285e-16
# 1792      -2.049643e-16 -2.049643e-16 -2.049643e-16 -2.049643e-16
#
# recipe_id        66            91            93            112     \
# user_id
# 1533       2.478637e-16  2.478637e-16  2.478637e-16  2.478637e-16
# 1535      -2.173745e-16 -2.173745e-16 -2.173745e-16 -2.173745e-16
# 1634      -1.837611e-16 -1.837611e-16 -1.837611e-16 -1.837611e-16
# 1676       4.099285e-16  4.099285e-16  4.099285e-16  4.099285e-16
# 1792      -2.049643e-16 -2.049643e-16 -2.049643e-16 -2.049643e-16
#
# recipe_id        142           143     ...        524958        524960  \
# user_id                                ...
# 1533       2.478637e-16  2.478637e-16  ...  2.478637e-16  2.478637e-16
# 1535      -2.173745e-16 -2.173745e-16  ... -2.173745e-16 -2.173745e-16
# 1634      -1.837611e-16 -1.837611e-16  ... -1.837611e-16 -1.837611e-16
# 1676       4.099285e-16  4.099285e-16  ...  4.099285e-16  4.099285e-16
# 1792      -2.049643e-16 -2.049643e-16  ... -2.049643e-16 -2.049643e-16
#
# recipe_id        528131        530004        530478        531172  \
# user_id
# 1533       2.478637e-16  2.478637e-16  2.478637e-16  2.478637e-16
# 1535      -2.173745e-16 -2.173745e-16 -2.173745e-16 -2.173745e-16
# 1634      -1.837611e-16 -1.837611e-16 -1.837611e-16 -1.837611e-16
# 1676       4.099285e-16  4.099285e-16  4.099285e-16  4.099285e-16
# 1792      -2.049643e-16 -2.049643e-16 -2.049643e-16 -2.049643e-16
#
# recipe_id        532740        534900        536119        536678
# user_id
# 1533       2.478637e-16  2.478637e-16  2.478637e-16  2.478637e-16
# 1535      -2.173745e-16 -2.173745e-16 -2.173745e-16 -2.173745e-16
# 1634      -1.837611e-16 -1.837611e-16 -1.837611e-16 -1.837611e-16
# 1676       4.099285e-16  4.099285e-16  4.099285e-16  4.099285e-16
# 1792      -2.049643e-16 -2.049643e-16 -2.049643e-16 -2.049643e-16
#
# [5 rows x 39670 columns]

# %%
# user similarity on replacing NAN by user avg
b = cosine_similarity(final_user)
np.fill_diagonal(b, 0 )
similarity_with_user = pd.DataFrame(b,index=final_user.index)
similarity_with_user.columns=final_user.index
similarity_with_user.head()
# Out:
# user_id    1533          1535          1634          1676          1792        \
# user_id
# 1533     0.000000e+00  1.108474e-03  5.896334e-03  3.119971e-28 -2.330883e-28
# 1535     1.108474e-03  0.000000e+00  1.046895e-29 -5.367374e-29  4.195889e-29
# 1634     5.896334e-03  1.046895e-29  0.000000e+00 -8.714682e-29  6.501569e-29
# 1676     3.119971e-28 -5.367374e-29 -8.714682e-29  0.000000e+00 -3.312674e-28
# 1792    -2.330883e-28  4.195889e-29  6.501569e-29 -3.312674e-28  0.000000e+00
#
# user_id    1891          2148          2178          2310          2312        \
# user_id
# 1533     3.690394e-28 -1.103125e-27  3.081488e-33  9.666505e-29  6.814081e-29
# 1535     2.338683e-03 -1.697550e-02  3.047755e-03  1.573654e-03  2.058606e-03
# 1634    -1.033063e-28  3.021501e-28  3.152333e-03 -1.290495e-02 -1.953989e-29
# 1676     5.284733e-28 -1.565986e-27 -9.244464e-33  1.338472e-28  9.791651e-29
# 1792    -3.926928e-28  1.172589e-27 -3.081488e-33 -1.044574e-28 -7.124799e-29
#
# user_id  ...    2001410644    2001415211    2001436530    2001453193  \
# user_id  ...
# 1533     ...  9.263510e-28 -1.402089e-28  4.007011e-28  1.924600e-29
# 1535     ... -1.681622e-28  2.492038e-29 -7.338043e-29 -2.805863e-30
# 1634     ... -2.575765e-28  3.889440e-29 -1.111419e-28 -5.278757e-30
# 1676     ...  1.317941e-27 -1.990455e-28  5.734024e-28  2.150795e-29
# 1792     ... -9.829095e-28  1.508492e-28 -4.256728e-28 -2.053191e-29
#
# user_id  2001497311    2001513060  2001524408    2001574271    2001704911  \
# user_id
# 1533            0.0 -6.199008e-29         0.0 -3.151569e-29  8.503794e-28
# 1535            0.0  1.043014e-29         0.0  5.325269e-30 -1.447970e-02
# 1634            0.0  1.728573e-29         0.0  8.447122e-30 -2.350778e-28
# 1676            0.0  1.290744e-02         0.0 -4.354383e-29  1.221653e-27
# 1792            0.0  6.537368e-29         0.0  3.313348e-29 -9.140395e-28
#
# user_id    2001836906
# user_id
# 1533    -1.406591e-28
# 1535     2.895940e-03
# 1634     3.926008e-29
# 1676    -2.016279e-28
# 1792     1.485061e-28
#
# [5 rows x 10000 columns]

# %%
# user similarity on replacing NAN by item(recipe) avg
cosine = cosine_similarity(final_recipe)
np.fill_diagonal(cosine, 0 )
similarity_with_recipe = pd.DataFrame(cosine,index=final_recipe.index)
similarity_with_recipe.columns=final_user.index
similarity_with_recipe.head()
# Out:
# user_id  1533        1535        1634        1676        1792        \
# user_id
# 1533       0.000000    0.983871    0.994094    0.998814    0.998474
# 1535       0.983871    0.000000    0.979897    0.984514    0.984179
# 1634       0.994094    0.979897    0.000000    0.994776    0.994438
# 1676       0.998814    0.984514    0.994776    0.000000    0.999124
# 1792       0.998474    0.984179    0.994438    0.999124    0.000000
#
# user_id  1891        2148        2178        2310        2312        ...  \
# user_id                                                              ...
# 1533       0.998462    0.998950    0.998128    0.994324    0.995196  ...
# 1535       0.984168    0.984425    0.983855    0.980139    0.981076  ...
# 1634       0.994427    0.994912    0.994109    0.990162    0.991174  ...
# 1676       0.999113    0.999600    0.998778    0.994972    0.995844  ...
# 1792       0.998773    0.999260    0.998438    0.994633    0.995505  ...
#
# user_id  2001410644  2001415211  2001436530  2001453193  2001497311  \
# user_id
# 1533       0.998914    0.998087    0.998667    0.996845    0.998932
# 1535       0.984613    0.983798    0.984369    0.982574    0.984631
# 1634       0.994877    0.994052    0.994630    0.992816    0.994894
# 1676       0.999564    0.998736    0.999317    0.997494    0.999582
# 1792       0.999224    0.998397    0.998977    0.997155    0.999242
#
# user_id  2001513060  2001524408  2001574271  2001704911  2001836906
# user_id
# 1533       0.996382    0.998967    0.996088    0.998950    0.996921
# 1535       0.982117    0.984658    0.981828    0.984594    0.982663
# 1634       0.992355    0.994929    0.992062    0.994912    0.992891
# 1676       0.997088    0.999617    0.996737    0.999600    0.997570
# 1792       0.996692    0.999277    0.996398    0.999260    0.997230
#
# [5 rows x 10000 columns]

# %%
def find_n_neighbours(df,n):
    order = np.argsort(df.values, axis=1)[:, :n]
    df = df.apply(lambda x: pd.Series(x.sort_values(ascending=False)
           .iloc[:n].index, 
          index=['top{}'.format(i) for i in range(1, n+1)]), axis=1)
    return df

# %%
# top 30 neighbours for each user
sim_user_30_u = find_n_neighbours(similarity_with_user,30)
sim_user_30_u.head()
# Out:
#             top1     top2    top3     top4    top5    top6    top7    top8  \
# user_id
# 1533       75805    48430   41799    35794  183872  114317  231507   68727
# 1535       30789  1328641  390553  1018899  177019  356985   81177  408707
# 1634     2185662   167527  478964   258739   66899  978876  394077   69260
# 1676      433588   135542  177806   467341  304596   57491  173880   88826
# 1792      105125   798181  289117    58469  160947   35106  600023  212497
#
#            top9   top10  ...   top21   top22       top23   top24   top25  \
# user_id                  ...
# 1533     403729  104600  ...  120908  326540       43083   16667   59064
# 1535     637016   55225  ...  105692   82227      437679   28345  152393
# 1634     180406  599284  ...   28170  375186       66987  145375   41654
# 1676     382007  302618  ...  344512  644902  2001513060  226989  214116
# 1792     139369  464189  ...   39394  142463      222564  592474  285041
#
#            top26    top27    top28   top29    top30
# user_id
# 1533      222064   463319   111045  573090  1363987
# 1535      416537   189500   860538  225896   574083
# 1634     1361337  1588002  1139501   29794    78884
# 1676      130219   106867   369956   57324  1145840
# 1792      333562  1355867   840181  482583   237533
#
# [5 rows x 30 columns]

# %%
# top 30 neighbours for each user
sim_user_30_m = find_n_neighbours(similarity_with_recipe,30)
sim_user_30_m.head()
# Out:
#             top1    top2    top3    top4    top5    top6     top7     top8  \
# user_id
# 1533       75805  257653  491230  358905  158278   66398  1486414   321172
# 1535      408707   16334   89015  128835  181319   30789  2584272   195534
# 1634     2185662  121807   66899  257653  491230  158278   358905    66398
# 1676      177806  257653  491230  158278  358905   66398  1486414   321172
# 1792      167140  167134  257653  491230  158278  358905    66398  1486414
#
#             top9   top10  ...    top21   top22    top23    top24    top25  \
# user_id                   ...
# 1533       65166  139238  ...  1346699  125736  2584272   186275   213467
# 1535      487266  366385  ...   134543  238046    18347   346101    92337
# 1634     1486414  321172  ...   641632  335157   238046  1346699   125736
# 1676       65166  139238  ...   335157  238046  1346699   125736  2584272
# 1792      321172   65166  ...   163576  238046  1346699   125736  2584272
#
#            top26   top27   top28    top29    top30
# user_id
# 1533      164293  222535  226892  1142572   319539
# 1535      170853  239988  252729   266403   308474
# 1634     2584272  186275  213467   164293   222535
# 1676      186275  213467  164293   222535  1142572
# 1792      186275  213467  164293   222535   226892
#
# [5 rows x 30 columns]

# %%
def get_user_similar_movies( user1, user2 ):
    common_recipes = rating_avg[rating_avg.user_id == user1].merge(
    rating_avg[rating_avg.user_id == user2],
    on = "recipe_id",
    how = "inner" )
    return common_recipes.merge(df_recipes, on = 'recipe_id' )

# %%
a = get_user_similar_movies(353579,255338)
a = a.loc[ : , ['rating_x_x','rating_x_y','name']]
a.head()
# Out:
#    rating_x_x  rating_x_y                                               name
# 0           4           5  andes crme de menthe cookies   andes mint cookies
# 1           4           5                                 crispy ginger beef
# 2           5           5                             sue b s chocolate cake
# 3           5           5             schnecken  sticky german cinnamon buns
# 4           5           5                                   teriyaki delight

# %%
df_sampleusers
# Out:
#          user_id  recipe_id  rating  \
# 8          76535     134728       4
# 12        468945     134728       0
# 13        255338     134728       5
# 20        202555     225241       5
# 21        353579     225241       5
# ...          ...        ...     ...
# 1132322   482933     290157       5
# 1132354   143592      82303       5
# 1132355   140132      82303       5
# 1132356   199020      82303       5
# 1132357  1122988      82303       5
#
#                                                     review
# 8                                               Very good!
# 12       Made my own buttermilk w/ vinegar and milk.  U...
# 13       First time using liquid smoke in a recipe. Mad...
# 20       My husband has just found out that he had to c...
# 21       Very good, made with ingredients I usually hav...
# ...                                                    ...
# 1132322  Perfect combination of flavors!  I used this f...
# 1132354  I will never buy hot fudge again. This is so q...
# 1132355  This is fabulous.  I made it for our dessert t...
# 1132356  5 stars for taste! I had a hard time getting m...
# 1132357  This was amazingly delicious!  The only change...
#
# [487266 rows x 4 columns]

# %%
def User_item_score(user,item):
    a = sim_user_30_m[sim_user_30_m.index==user].values
    b = a.squeeze().tolist()
    c = final_recipe.loc[:,item]
    d = c[c.index.isin(b)]
    f = d[d.notnull()]
    avg_user = Mean.loc[Mean['user_id'] == user,'rating'].values[0]
    index = f.index.values.squeeze().tolist()
    corr = similarity_with_recipe.loc[user,index]
    fin = pd.concat([f, corr], axis=1)
    fin.columns = ['adg_score','correlation']
    fin['score']=fin.apply(lambda x:x['adg_score'] * x['correlation'],axis=1)
    nume = fin['score'].sum()
    deno = fin['correlation'].sum()
    final_score = avg_user + (nume/deno)
    return final_score

# %%
rating_avg = rating_avg.astype({"recipe_id": str})
recipe_user = rating_avg.groupby(by = 'user_id')['recipe_id'].apply(lambda x:','.join(x))

# %%
def User_item_score1(user):
    recipes_made_by_user = check.columns[check[check.index==user].notna().any()].tolist()
    a = sim_user_30_m[sim_user_30_m.index==user].values
    b = a.squeeze().tolist()
    d = recipe_user[recipe_user.index.isin(b)]
    l = ','.join(d.values)
    recipes_made_by_similar_users = l.split(',')
    recipes_under_consideration = list(set(recipes_made_by_similar_users)-set(list(map(str, recipes_made_by_user))))
    recipes_under_consideration = list(map(int, recipes_under_consideration))
    score = []
    for item in recipes_under_consideration:
        c = final_recipe.loc[:,item]
        d = c[c.index.isin(b)]
        f = d[d.notnull()]
        avg_user = Mean.loc[Mean['user_id'] == user,'rating'].values[0]
        index = f.index.values.squeeze().tolist()
        corr = similarity_with_recipe.loc[user,index]
        fin = pd.concat([f, corr], axis=1)
        fin.columns = ['adg_score','correlation']
        fin['score']=fin.apply(lambda x:x['adg_score'] * x['correlation'],axis=1)
        nume = fin['score'].sum()
        deno = fin['correlation'].sum()
        final_score = avg_user + (nume/deno)
        score.append(final_score)
    data = pd.DataFrame({'recipe_id':recipes_under_consideration,'score':score})
    top_5_recommendation = data.sort_values(by='score',ascending=False).head(5)
    Recipe_Name = top_5_recommendation.merge(df_recipes, how='inner', on='recipe_id')
    Recipe_Names = Recipe_Name.name.values.tolist()
    return Recipe_Names

# %%
user = int(input("Enter the user id to whom you want to recommend : "))
predicted_recipes = User_item_score1(user)
print(" ")
print("The Recommendations for User Id : {}".format(user))
print("   ")
for i in predicted_recipes:
    print(i)
# Out:
# Enter the user id to whom you want to recommend : 202555
#
# The Recommendations for User Id : 202555
#
# raspberry sherbet punch
# meatballs with sauerkraut
# a 1 dumplings
# uncle bill s broccoli soup
# cheesy alfredo sauce supreme

# %% [markdown]
# # Market Basket Analysis

# %% [markdown]
# It will be used in our case, the list of ingredients for recipes as our basket. It is interesting to analyse this scenario because companies that sell professional products for chefs or restaurants, may benefit from the analysis verifying which kind of products are necessary together in order to produce certain food.

# %%
#measures = ['teaspoon', 't', 'tsp.', 'tablespoon', 'T', 'tbl.', 'tb', 'tbsp.', 'fluid ounce', 'fl oz', 'gill', 'cup', 'c', 'pint', 'p', 'pt', 'fl pt', 'quart', 'q', 'qt', 'fl qt', 'gallon', 'g', 'gal', 'ml', 'milliliter', 'millilitre', 'cc', 'mL', 'l', 'liter', 'litre', 'L', 'dl', 'deciliter', 'decilitre', 'dL', 'bulb', 'level', 'heaped', 'rounded', 'whole', 'pinch', 'medium', 'slice', 'pound', 'lb', '#', 'ounce', 'oz', 'mg', 'milligram', 'milligramme', 'g', 'gram', 'gramme', 'kg', 'kilogram', 'kilogramme', 'x', 'of', 'mm', 'millimetre', 'millimeter', 'cm', 'centimeter', 'centimetre', 'm', 'meter', 'metre', 'inch', 'in', 'milli', 'centi', 'deci', 'hecto', 'kilo']
#words_to_remove = ['fresh', 'oil', 'a', 'red', 'bunch', 'and', 'clove', 'or', 'leaf', 'chilli', 'large', 'extra', 'sprig', 'ground', 'handful', 'free', 'small', 'pepper', 'virgin', 'range', 'from', 'dried', 'sustainable', 'black', 'peeled', 'higher', 'welfare', 'seed', 'for', 'finely', 'freshly', 'sea', 'quality', 'white', 'ripe', 'few', 'piece', 'source', 'to', 'organic', 'flat', 'smoked', 'ginger', 'sliced', 'green', 'picked', 'the', 'stick', 'plain', 'plus', 'mixed', 'mint', 'bay', 'basil', 'your', 'cumin', 'optional', 'fennel', 'serve', 'mustard', 'unsalted', 'baby', 'paprika', 'fat', 'ask', 'natural', 'skin', 'roughly', 'into', 'such', 'cut', 'good', 'brown', 'grated', 'trimmed', 'oregano', 'powder', 'yellow', 'dusting', 'knob', 'frozen', 'on', 'deseeded', 'low', 'runny', 'balsamic', 'cooked', 'streaky', 'nutmeg', 'sage', 'rasher', 'zest', 'pin', 'groundnut', 'breadcrumb', 'turmeric', 'halved', 'grating', 'stalk', 'light', 'tinned', 'dry', 'soft', 'rocket', 'bone', 'colour', 'washed', 'skinless', 'leftover', 'splash', 'removed', 'dijon', 'thick', 'big', 'hot', 'drained', 'sized', 'chestnut', 'watercress', 'fishmonger', 'english', 'dill', 'caper', 'raw', 'worcestershire', 'flake', 'cider', 'cayenne', 'tbsp', 'leg', 'pine', 'wild', 'if', 'fine', 'herb', 'almond', 'shoulder', 'cube', 'dressing', 'with', 'chunk', 'spice', 'thumb', 'garam', 'new', 'little', 'punnet', 'peppercorn', 'shelled', 'saffron', 'other''chopped', 'salt', 'olive', 'taste', 'can', 'sauce', 'water', 'diced', 'package', 'italian', 'shredded', 'divided', 'parsley', 'vinegar', 'all', 'purpose', 'crushed', 'juice', 'more', 'coriander', 'bell', 'needed', 'thinly', 'boneless', 'half', 'thyme', 'cubed', 'cinnamon', 'cilantro', 'jar', 'seasoning', 'rosemary', 'extract', 'sweet', 'baking', 'beaten', 'heavy', 'seeded', 'tin', 'vanilla', 'uncooked', 'crumb', 'style', 'thin', 'nut', 'coarsely', 'spring', 'chili', 'cornstarch', 'strip', 'cardamom', 'rinsed', 'honey', 'cherry', 'root', 'quartered', 'head', 'softened', 'container', 'crumbled', 'frying', 'lean', 'cooking', 'roasted', 'warm', 'whipping', 'thawed', 'corn', 'pitted', 'sun', 'kosher', 'bite', 'toasted', 'lasagna', 'split', 'melted', 'degree', 'lengthwise', 'romano', 'packed', 'pod', 'anchovy', 'rom', 'prepared', 'juiced', 'fluid', 'floret', 'room', 'active', 'seasoned', 'mix', 'deveined', 'lightly', 'anise', 'thai', 'size', 'unsweetened', 'torn', 'wedge', 'sour', 'basmati', 'marinara', 'dark', 'temperature', 'garnish', 'bouillon', 'loaf', 'shell', 'reggiano', 'canola', 'parmigiano', 'round', 'canned', 'ghee', 'crust', 'long', 'broken', 'ketchup', 'bulk', 'cleaned', 'condensed', 'sherry', 'provolone', 'cold', 'soda', 'cottage', 'spray', 'tamarind', 'pecorino', 'shortening', 'part', 'bottle', 'sodium', 'cocoa', 'grain', 'french', 'roast', 'stem', 'link', 'firm', 'asafoetida', 'mild', 'dash', 'boiling']

# %%
df_recipes['ingredients']
# Out:
# 0        [butter, granulated sugar, eggs, bananas, all-...
# 1        [beef roast, brown gravy mix, dried italian sa...
# 2        [boneless chicken breasts, black beans, corn, ...
# 3        [boneless skinless chicken breast halves, ling...
# 4        [bananas, lemon juice, flour, baking soda, sal...
#                                ...
# 39995    [ginger, garlic, soy sauce, granulated sugar, ...
# 39996    [round steaks, vegetable oil, minced garlic cl...
# 39997    [vanilla ice cream, frosted flakes, cinnamon, ...
# 39998    [fresh chinese noodles, oyster sauce, rice win...
# 39999    [ground beef, bacon, onion, ketchup, salt, bro...
# Name: ingredients, Length: 40000, dtype: object

# %%
ingredients = df_recipes['ingredients'].values.tolist()

# %%
ingredients
# Out:
# [['butter',
#   'granulated sugar',
#   'eggs',
#   'bananas',
#   'all-purpose flour',
#   'baking soda',
#   'salt',
#   'vanilla'],
#  ['beef roast',
#   'brown gravy mix',
#   'dried italian salad dressing mix',
#   'ranch dressing mix',
#   'water'],
#  ['boneless chicken breasts', 'black beans', 'corn', 'salsa', 'cream cheese'],
#  ['boneless skinless chicken breast halves',
#   'linguine',
#   'cajun seasoning',
#   'butter',
#   'green onion',
#   'heavy whipping cream',
#   'sun-dried tomatoes',
#   'salt',
#   'dried basil',
#   'ground black pepper',
#   'garlic powder',
#   'parmesan cheese'],
#  ['bananas',
#   'lemon juice',
#   'flour',
#   'baking soda',
#   'salt',
#   'butter',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'buttermilk',
#   'cream cheese',
#   'icing sugar',
#   'walnuts'],
#  ['ground beef',
#   'bread',
#   'egg',
#   'vidalia onions',
#   'table salt',
#   'black pepper',
#   'ketchup',
#   'whole milk',
#   'apple cider vinegar',
#   'dark brown sugar'],
#  ['italian sausage',
#   'onion',
#   'garlic cloves',
#   'diced tomatoes',
#   'tomato paste',
#   'tomato sauce',
#   'water',
#   'basil',
#   'dried parsley flakes',
#   'brown sugar',
#   'salt',
#   'crushed red pepper flakes',
#   'fresh coarse ground black pepper',
#   'red wine',
#   'thin spaghetti',
#   'parmesan cheese'],
#  ['butter',
#   'unsweetened cocoa',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'flour',
#   'salt',
#   'chocolate chips',
#   'raisins',
#   'maraschino cherry',
#   'nuts',
#   "m&m'",
#   "reese's pieces",
#   'miniature marshmallow'],
#  ['ground beef',
#   'egg',
#   'parmesan cheese',
#   'breadcrumbs',
#   'garlic',
#   'salt',
#   'fresh ground black pepper',
#   'milk',
#   'dried oregano',
#   'fresh parsley'],
#  ['chicken drumsticks',
#   'water',
#   'balsamic vinegar',
#   'soy sauce',
#   'sugar',
#   'garlic clove',
#   'hot chili pepper'],
#  ['ground beef',
#   'yellow onion',
#   'taco seasoning',
#   'flour tortillas',
#   'refried beans',
#   'taco cheese',
#   'cream of mushroom soup',
#   'sour cream',
#   'hot sauce'],
#  ['butter',
#   'garlic',
#   'garlic powder',
#   'seasoning salt',
#   'seasoned dry bread crumb',
#   'cheddar cheese',
#   'parmesan cheese',
#   'ground black pepper',
#   'boneless skinless chicken breasts',
#   'shredded cheddar cheese'],
#  ['all-purpose flour',
#   'baking soda',
#   'salt',
#   'butter',
#   'brown sugar',
#   'eggs',
#   'bananas'],
#  ['picante sauce',
#   'ground cumin',
#   'dried oregano leaves',
#   'cooked chicken',
#   'cheddar cheese',
#   'green onions',
#   'flour tortillas',
#   'margarine',
#   'green onion'],
#  ['macaroni',
#   'butter',
#   'flour',
#   'milk',
#   'cream',
#   'salt',
#   'fresh ground black pepper',
#   'cheddar cheese',
#   'breadcrumbs'],
#  ['unbleached all-purpose flour',
#   'baking soda',
#   'baking powder',
#   'kosher salt',
#   'unsalted butter',
#   'buttermilk'],
#  ['cornstarch',
#   'water',
#   'garlic powder',
#   'boneless round steak',
#   'vegetable oil',
#   'broccoli florets',
#   'onion',
#   'reduced sodium soy sauce',
#   'brown sugar',
#   'ground ginger',
#   'cooked rice',
#   'toasted sesame seeds'],
#  ['potato',
#   'onion',
#   'celery',
#   'carrot',
#   'margarine',
#   'all-purpose flour',
#   'chicken broth',
#   'half-and-half',
#   'salt',
#   'pepper',
#   'chicken',
#   'pie crusts'],
#  ['chicken breast',
#   'onion',
#   'vegetable oil',
#   'flour tortillas',
#   'monterey jack cheese',
#   'butter',
#   'flour',
#   'chicken broth',
#   'sour cream',
#   'green chilies'],
#  ['salt',
#   'paprika',
#   'cayenne pepper',
#   'onion powder',
#   'thyme',
#   'white pepper',
#   'garlic powder',
#   'black pepper',
#   'roasting chicken',
#   'onion'],
#  ['ground beef',
#   'celery',
#   'onion',
#   'tomato sauce',
#   'ketchup',
#   'barbecue sauce',
#   'brown sugar',
#   'dry mustard',
#   'salt and pepper',
#   'worcestershire sauce',
#   'vinegar'],
#  ['chicken broth',
#   'potatoes',
#   'seasoning salt',
#   'white pepper',
#   'ground red pepper',
#   'cream cheese'],
#  ['butter',
#   'sugar',
#   'eggs',
#   'flour',
#   'cream of tartar',
#   'baking soda',
#   'salt',
#   'cinnamon',
#   'vanilla extract'],
#  ['pork ribs',
#   'light brown sugar',
#   'hickory smoke salt',
#   'paprika',
#   'garlic powder',
#   'ground red pepper',
#   'barbecue sauce'],
#  ['flour', 'sugar', 'salt', 'baking powder', 'eggs', 'butter', 'milk'],
#  ["devil's food cake mix", 'vegetable oil', 'eggs', "confectioners' sugar"],
#  ['pork chops',
#   'chicken broth',
#   'honey',
#   'soy sauce',
#   'ketchup',
#   'ginger',
#   'garlic salt'],
#  ['italian sausage',
#   'russet baking potatoes',
#   'vidalia onion',
#   'cooked bacon',
#   'accent seasoning',
#   'salt',
#   'black pepper',
#   'red pepper flakes',
#   'garlic cloves',
#   'kale',
#   'chicken broth',
#   'water',
#   'flour',
#   'heavy whipping cream'],
#  ['all-purpose flour',
#   'sugar',
#   'milk',
#   'vanilla',
#   'baking powder',
#   'salt',
#   'egg',
#   'brown sugar',
#   'cinnamon',
#   'butter',
#   'walnuts'],
#  ['pork roast', 'onions', 'ginger ale', 'barbecue sauce'],
#  ['graham cracker crumbs',
#   "confectioners' sugar",
#   'peanut butter',
#   'butter',
#   'milk chocolate chips'],
#  ['potatoes',
#   'garlic cloves',
#   'olive oil',
#   'water',
#   'dried oregano',
#   'lemon',
#   'sea salt',
#   'fresh coarse ground black pepper'],
#  ['carrots',
#   'celery',
#   'onions',
#   'garlic powder',
#   'salt',
#   'pepper',
#   'corn oil',
#   'chicken broth',
#   'tomatoes',
#   'rotel tomatoes & chilies',
#   'taco seasoning',
#   'corn',
#   'chicken meat',
#   'milk',
#   'monterey jack cheese',
#   'corn tortilla chips'],
#  ['oil',
#   'onions',
#   'garlic',
#   'lean ground beef',
#   'beef sirloin',
#   'diced tomatoes',
#   'dark beer',
#   'strong coffee',
#   'tomato paste',
#   'beef broth',
#   'brown sugar',
#   'chili sauce',
#   'cumin',
#   'cocoa',
#   'oregano',
#   'cayenne',
#   'coriander',
#   'salt',
#   'kidney beans',
#   'chili peppers'],
#  ['butter',
#   'granulated sugar',
#   'eggs',
#   'vanilla',
#   'baking powder',
#   'salt',
#   'all-purpose flour',
#   'milk',
#   'fresh blueberries',
#   'lemon zest',
#   'ground nutmeg'],
#  ['vegetable oil',
#   'ginger',
#   'garlic',
#   'soy sauce',
#   'water',
#   'dark brown sugar',
#   'flank steak',
#   'cornstarch',
#   'green onions'],
#  ['sweet butter',
#   'olive oil',
#   'garlic cloves',
#   'heavy cream',
#   'white pepper',
#   'parmesan cheese',
#   'mozzarella cheese',
#   'angel hair pasta',
#   'parsley',
#   'cracked black pepper'],
#  ['boneless chicken breast halves',
#   'mayonnaise',
#   'parmesan cheese',
#   'seasoning salt',
#   'ground black pepper',
#   'garlic powder'],
#  ['lean ground beef',
#   'italian sausage',
#   'onion',
#   'garlic cloves',
#   'salt',
#   'fresh coarse ground black pepper',
#   'dried parsley flakes',
#   'dried oregano',
#   'dried basil',
#   'whole tomatoes',
#   'ricotta cheese',
#   'eggs',
#   'pepper',
#   'parsley',
#   'parmesan cheese',
#   'mozzarella cheese',
#   'lasagna noodles'],
#  ['flour',
#   'baking soda',
#   'baking powder',
#   'salt',
#   'bananas',
#   'sugar',
#   'egg',
#   'butter',
#   'brown sugar',
#   'cinnamon',
#   'nuts'],
#  ['dry yeast',
#   'milk',
#   'granulated sugar',
#   'margarine',
#   'salt',
#   'eggs',
#   'flour',
#   'brown sugar',
#   'cinnamon',
#   'powdered sugar',
#   'cream cheese',
#   'vanilla'],
#  ['elbow macaroni',
#   'butter',
#   'all-purpose flour',
#   'salt',
#   'black pepper',
#   'milk',
#   'shredded cheddar cheese'],
#  ['butter',
#   'onion',
#   'flour',
#   'half-and-half cream',
#   'chicken stock',
#   'fresh broccoli',
#   'carrot',
#   'nutmeg',
#   'sharp cheddar cheese',
#   'salt and pepper',
#   'crusty bread',
#   'whole milk'],
#  ['sugar',
#   'flour',
#   'baking cocoa',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'eggs',
#   'milk',
#   'vegetable oil',
#   'vanilla extract',
#   'boiling water'],
#  ['onion',
#   'garlic cloves',
#   'olive oil',
#   'ground beef',
#   'stewed tomatoes',
#   'water',
#   'elbow macaroni',
#   'salt',
#   'pepper',
#   'parmesan cheese'],
#  ['butter',
#   "confectioners' sugar",
#   'half-and-half cream',
#   'vanilla',
#   'unsweetened cocoa powder'],
#  ['flour', 'baking powder', 'salt', 'sugar', 'eggs', 'butter', 'milk'],
#  ['tomatoes',
#   'onions',
#   'green peppers',
#   'jalapeno pepper',
#   'garlic cloves',
#   'cumin',
#   'pepper',
#   'canning salt',
#   'sugar',
#   'vinegar',
#   'tomato sauce',
#   'tomato paste'],
#  ['ground beef',
#   'eggs',
#   'milk',
#   'breadcrumbs',
#   'salt',
#   'fresh parsley',
#   'garlic powder',
#   'fresh ground pepper',
#   'locatelli cheese'],
#  ['pillsbury refrigerated crescent dinner rolls',
#   'cream of chicken soup',
#   'cheddar cheese',
#   '18% table cream',
#   'cream cheese',
#   'butter',
#   'garlic powder',
#   'onion',
#   'cooked chicken breasts',
#   'seasoning salt',
#   'ground black pepper',
#   'mayonnaise'],
#  ['flour', 'sugar', 'baking powder', 'salt', 'soymilk', 'vegetable oil'],
#  ['spaghettini',
#   'soy sauce',
#   'sesame oil',
#   'sugar',
#   'scallions',
#   'sesame seeds',
#   'teriyaki sauce',
#   'garlic cloves',
#   'brown sugar',
#   'fresh ginger',
#   'boneless skinless chicken breasts'],
#  ['tilapia fillets',
#   'lemon juice',
#   'parmesan cheese',
#   'butter',
#   'mayonnaise',
#   'green onions',
#   'seasoning salt',
#   'dried basil',
#   'black pepper',
#   'hot pepper sauce'],
#  ['peanut butter', 'granulated sugar', 'egg', 'sugar'],
#  ['pork back ribs',
#   'honey',
#   'paprika',
#   'chili powder',
#   'garlic powder',
#   'old bay seasoning',
#   'onion powder',
#   'celery salt',
#   'dark brown sugar',
#   'fresh ground pepper',
#   'onion',
#   'barbecue sauce',
#   'white sugar'],
#  ['all-purpose flour',
#   'baking soda',
#   'baking powder',
#   'salt',
#   'ground cinnamon',
#   'white sugar',
#   'vegetable oil',
#   'eggs',
#   'vanilla extract',
#   'carrots',
#   'flaked coconut',
#   'walnuts',
#   'crushed pineapple',
#   'cream cheese',
#   'butter',
#   'icing sugar'],
#  ['eggs',
#   'whole milk',
#   'flour',
#   'sugar',
#   'vanilla',
#   'salt',
#   'cinnamon',
#   'texas toast thick bread',
#   'butter',
#   'powdered sugar',
#   'syrup'],
#  ['frozen hash browns',
#   'margarine',
#   'cream of chicken soup',
#   'sour cream',
#   'onion',
#   'cheddar cheese',
#   'salt',
#   'pepper'],
#  ['olive oil',
#   'sweet italian sausage link',
#   'dried red pepper flakes',
#   'onion',
#   'garlic',
#   'italian plum tomatoes',
#   'whipping cream',
#   'salt',
#   'pasta',
#   'parsley',
#   'parmesan cheese'],
#  ['all-purpose flour',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'ground ginger',
#   'ground cinnamon',
#   'ground cloves',
#   'unsalted butter',
#   'dark brown sugar',
#   'egg',
#   'molasses',
#   'vanilla',
#   'lemon zest'],
#  ['butter',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'almond extract',
#   'all-purpose flour',
#   'baking soda',
#   'baking powder',
#   'salt',
#   "confectioners' sugar",
#   'milk',
#   'light corn syrup',
#   'food coloring'],
#  ['boneless skinless chicken breasts',
#   'dry breadcrumbs',
#   'parmesan cheese',
#   'seasoning salt',
#   'ground black pepper',
#   'garlic powder',
#   'ranch salad dressing',
#   'butter'],
#  ['pork tenderloin', 'salt and pepper', 'seasoning'],
#  ['pastry for single-crust pie',
#   'sugar',
#   'flour',
#   'cinnamon',
#   'nutmeg',
#   'allspice',
#   'salt',
#   'apples',
#   'brown sugar',
#   'quick-cooking rolled oats',
#   'butter',
#   'pecans'],
#  ['water',
#   'egg',
#   'vegetable oil',
#   'bread flour',
#   'sugar',
#   'salt',
#   'instant yeast',
#   'butter',
#   'shortening'],
#  ['all-purpose flour',
#   'active dry yeast',
#   'salt',
#   'warm water',
#   'olive oil',
#   'cornmeal'],
#  ['water',
#   'salt',
#   'lentils',
#   'onion',
#   'quick-cooking oats',
#   'cheddar cheese',
#   'egg',
#   'spaghetti sauce',
#   'garlic powder',
#   'dried basil',
#   'dried parsley',
#   'seasoning salt',
#   'black pepper'],
#  ['oil',
#   'boneless skinless chicken breasts',
#   'water chestnut',
#   'mushroom',
#   'onions',
#   'garlic',
#   'iceberg lettuce',
#   'sugar',
#   'water',
#   'soy sauce',
#   'rice wine vinegar',
#   'ketchup',
#   'lemon juice',
#   'sesame oil',
#   'hot mustard',
#   'garlic and red chile paste',
#   'brown sugar'],
#  ['all-purpose flour',
#   'salt',
#   'baking powder',
#   'baking soda',
#   'unsweetened cocoa powder',
#   'sugar',
#   'vegetable oil',
#   'hot coffee',
#   'milk',
#   'eggs',
#   'vanilla',
#   'butter',
#   'shortening'],
#  ['olive oil',
#   'white onion',
#   'zucchini',
#   'italian cut green beans',
#   'celery',
#   'garlic',
#   'vegetable broth',
#   'red kidney beans',
#   'small white beans',
#   'diced tomatoes',
#   'carrot',
#   'fresh parsley',
#   'dried oregano',
#   'salt',
#   'ground black pepper',
#   'dried basil',
#   'dried thyme',
#   'hot water',
#   'baby spinach',
#   'small shell pasta'],
#  ['red potatoes',
#   'garlic cloves',
#   'butter',
#   'milk',
#   'salt',
#   'parmesan cheese'],
#  ['boneless skinless chicken breasts',
#   'condensed cream of chicken soup',
#   'condensed cheddar cheese soup',
#   'garlic powder',
#   'salt and pepper'],
#  ['cabbage',
#   'carrot',
#   'onions',
#   'granulated sugar',
#   'salt',
#   'pepper',
#   'milk',
#   'mayonnaise',
#   'buttermilk',
#   'white vinegar',
#   'lemon juice'],
#  ["devil's food cake mix",
#   'instant chocolate pudding mix',
#   'semi-sweet chocolate chips',
#   'water',
#   'eggs',
#   'vanilla extract',
#   'cocoa',
#   'butter',
#   'powdered sugar',
#   'hot water'],
#  ['olive oil',
#   'butter',
#   'onion',
#   'celery',
#   'garlic clove',
#   'tomato sauce',
#   'tomato paste',
#   'parmesan cheese',
#   'dried basil',
#   'dried oregano',
#   'salt',
#   'sugar',
#   'black pepper',
#   'bay leaf',
#   'fennel seed'],
#  ['water',
#   'light soy sauce',
#   'vegetable oil',
#   'lemon pepper seasoning',
#   'garlic cloves',
#   'pork loin chops'],
#  ['olive oil',
#   'lemon, juice of',
#   'dried oregano',
#   'garlic',
#   'dried basil',
#   'red wine vinegar',
#   'salt',
#   'sugar',
#   'fresh ground black pepper',
#   'romaine lettuce',
#   'plum tomatoes',
#   'english cucumber',
#   'red onion',
#   'green bell pepper',
#   'feta cheese',
#   'kalamata olive'],
#  ['cauliflower',
#   'garlic cloves',
#   'fresh rosemary',
#   'salt',
#   'black pepper',
#   'olive oil'],
#  ['oreo cookies', 'cream cheese', 'white chocolate bark', 'chocolate bark'],
#  ['penne',
#   'butter',
#   'garlic cloves',
#   'flour',
#   'chicken broth',
#   'milk',
#   'parsley flakes',
#   'salt and pepper',
#   'parmesan cheese'],
#  ['white cake mix',
#   'all-purpose flour',
#   'granulated sugar',
#   'salt',
#   'water',
#   'vegetable oil',
#   'real vanilla',
#   'almond extract',
#   'sour cream',
#   'egg whites'],
#  ['top sirloin steak',
#   'olive oil',
#   'lime juice',
#   'garlic clove',
#   'chili powder',
#   'cumin',
#   'hot pepper flakes',
#   'black pepper',
#   'salt',
#   'flour tortillas',
#   'onion',
#   'sweet peppers',
#   'salsa',
#   'sour cream',
#   'cheese',
#   'chopped tomato'],
#  ['creamy peanut butter',
#   'brown sugar',
#   'white sugar',
#   'butter',
#   'eggs',
#   'baking soda',
#   'baking powder',
#   'vanilla extract',
#   'flour'],
#  ['boneless skinless chicken',
#   'egg',
#   'salt',
#   'white pepper',
#   'oil',
#   'cornstarch',
#   'flour',
#   'soy sauce',
#   'orange juice',
#   'brown sugar',
#   'orange, zest of',
#   'gingerroot',
#   'garlic',
#   'red chili pepper flakes',
#   'green onion',
#   'rice wine',
#   'water',
#   'sesame oil'],
#  ['ground beef',
#   'olive oil',
#   'onion',
#   'garlic',
#   'bay leaves',
#   'oregano',
#   'dried basil',
#   'italian seasoning',
#   'salt',
#   'ground pepper',
#   'tomato paste',
#   'tomato sauce',
#   'diced tomatoes',
#   'fresh mushrooms',
#   'parmesan cheese'],
#  ['granny smith apples',
#   'brown sugar',
#   'flour',
#   'rolled oats',
#   'cinnamon',
#   'nutmeg',
#   'butter'],
#  ['nonfat beef broth',
#   'garlic cloves',
#   'tomato paste',
#   'cabbage',
#   'yellow onion',
#   'carrot',
#   'green beans',
#   'zucchini',
#   'basil',
#   'oregano',
#   'salt & pepper'],
#  ['bone-in ham', 'brown sugar', 'yellow mustard', 'aluminum foil'],
#  ['boneless skinless chicken breast',
#   'barbecue sauce',
#   'sweet onion',
#   'hamburger buns'],
#  ['butter',
#   'water',
#   'vanilla extract',
#   'salt',
#   'white sugar',
#   'unsweetened cocoa powder',
#   'flour',
#   'chocolate milk'],
#  ['potatoes', 'spices', 'vegetable oil'],
#  ['cocoa powder',
#   'shortening',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'flour',
#   'baking powder',
#   'salt',
#   'walnuts'],
#  ['chicken',
#   'brown sugar',
#   'vinegar',
#   'sprite',
#   'garlic',
#   'soy sauce',
#   'pepper'],
#  ['salt',
#   'paprika',
#   'cayenne pepper',
#   'onion powder',
#   'thyme',
#   'white pepper',
#   'garlic powder',
#   'black pepper',
#   'roasting chicken',
#   'onions'],
#  ['chicken',
#   'eggs',
#   'water',
#   'hot sauce',
#   'salt',
#   'fresh ground black pepper',
#   'garlic powder',
#   'all-purpose flour',
#   'baking powder'],
#  ['boneless skinless chicken breasts',
#   'salt',
#   'pepper',
#   'chicken broth',
#   'swiss cheese',
#   'cream of chicken soup',
#   'cream of mushroom soup',
#   'milk',
#   'pepperidge farm herb stuffing',
#   'butter'],
#  ['shrimp',
#   'olive oil',
#   'garlic cloves',
#   'red pepper flakes',
#   'steak seasoning',
#   'lemon, zest of',
#   'lemon juice',
#   'fresh parsley'],
#  ['lean ground beef',
#   'onion',
#   'garlic cloves',
#   'meatless sauce',
#   'chicken broth',
#   'dried oregano leaves',
#   'ziti pasta',
#   'mozzarella cheese',
#   'parmesan cheese'],
#  ['butter',
#   'all-purpose flour',
#   'icing sugar',
#   'vanilla extract',
#   'red maraschino cherry',
#   'green maraschino cherry'],
#  ['ground beef',
#   'onions',
#   'garlic',
#   'fresh ginger',
#   'dry crushed red pepper',
#   'sesame oil',
#   'cornstarch',
#   'beef broth',
#   'hoisin sauce',
#   'soy sauce',
#   'vermicelli',
#   'green onion'],
#  ['soy sauce',
#   'water',
#   'ground ginger',
#   'garlic powder',
#   'brown sugar',
#   'honey',
#   'cornstarch',
#   'cold water'],
#  ['pepperoni', 'cream cheese', 'pillsbury refrigerated crescent dinner rolls'],
#  ['milk',
#   'butter',
#   'sugar',
#   'eggs',
#   'salt',
#   'bread flour',
#   'active dry yeast'],
#  ['chicken legs',
#   'olive oil',
#   'soy sauce',
#   'ketchup',
#   'honey',
#   'garlic cloves',
#   'salt and pepper'],
#  ['flour',
#   'baking powder',
#   'salt',
#   'sugar',
#   'eggs',
#   'vegetable oil',
#   'milk',
#   'vanilla'],
#  ['whole chicken',
#   'oil',
#   'margarine',
#   'lemon juice',
#   'seasoning salt',
#   'garlic powder',
#   'fresh ground black pepper',
#   'cayenne pepper',
#   'lemon'],
#  ['brussels sprouts', 'olive oil', 'kosher salt', 'lemon-pepper seasoning'],
#  ['green peppers',
#   'beef',
#   'onion',
#   'tomatoes',
#   'long grain rice',
#   'water',
#   'salt',
#   'worcestershire sauce',
#   'cheddar cheese'],
#  ['spaghetti',
#   'milk',
#   'egg',
#   'ground beef',
#   'onion',
#   'green bell pepper',
#   'garlic cloves',
#   'chili powder',
#   'cumin',
#   'oregano',
#   'salt',
#   'pepper',
#   'tomato sauce',
#   'shredded cheddar cheese',
#   'monterey jack cheese'],
#  ['ground beef',
#   'onion',
#   'carrots',
#   'celery',
#   'diced tomatoes',
#   'red kidney beans',
#   'white kidney beans',
#   'beef stock',
#   'oregano',
#   'pepper',
#   'parsley',
#   'tabasco sauce',
#   'spaghetti sauce',
#   'pasta'],
#  ['all-purpose flour',
#   'sugar',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'milk',
#   'eggs',
#   'vanilla',
#   'vegetable oil'],
#  ['avocados',
#   'garlic cloves',
#   'lime',
#   'tomatoes',
#   'onion',
#   'salt',
#   'cilantro',
#   'jalapeno peppers'],
#  ['cider vinegar',
#   'whole grain mustard',
#   'garlic',
#   'lime',
#   'lemon',
#   'brown sugar',
#   'salt',
#   'olive oil',
#   'ground black pepper',
#   'boneless skinless chicken breast halves'],
#  ['brown sugar',
#   'white sugar',
#   'butter flavor crisco',
#   'creamy peanut butter',
#   'salt',
#   'eggs',
#   'vanilla',
#   'baking soda',
#   'flour'],
#  ['taco seasoning', 'chicken broth', 'boneless skinless chicken breast'],
#  ['chicken thigh',
#   'eggs',
#   'cornstarch',
#   'dried chili pods',
#   'rice vinegar',
#   'rice wine',
#   'sugar',
#   'soy sauce'],
#  ['all-purpose flour',
#   'baking powder',
#   'salt',
#   'unsalted butter',
#   'brown sugar',
#   'granulated sugar',
#   'egg',
#   'egg yolk',
#   'vanilla extract',
#   'chocolate chips',
#   'walnuts'],
#  ['fat-free mayonnaise',
#   'onion',
#   'eggplant',
#   'fine dry breadcrumb',
#   'parmesan cheese',
#   'dried italian seasoning',
#   'vegetable oil cooking spray'],
#  ['pork chops',
#   'garlic powder',
#   'seasoning salt',
#   'eggs',
#   'all-purpose flour',
#   'italian style breadcrumbs',
#   'olive oil',
#   'condensed cream of mushroom soup',
#   'milk',
#   'white wine'],
#  ['eggs',
#   'raisins',
#   'vanilla',
#   'butter',
#   'brown sugar',
#   'white sugar',
#   'flour',
#   'salt',
#   'cinnamon',
#   'baking soda',
#   'oatmeal',
#   'pecans'],
#  ['unsalted butter',
#   "confectioners' sugar",
#   'milk',
#   'vanilla extract',
#   'salt'],
#  ['green cabbage', 'butter', 'salt and pepper'],
#  ['pork butt',
#   'black pepper',
#   'paprika',
#   'turbinado sugar',
#   'salt',
#   'dry mustard',
#   'cayenne',
#   'chicken stock',
#   'dry white wine',
#   'apple cider vinegar',
#   'molasses',
#   'plum tomato',
#   'shallots',
#   'pitted dates',
#   'garlic'],
#  ['flour',
#   'sugar',
#   'baking soda',
#   'baking powder',
#   'salt',
#   'sour cream',
#   'eggs',
#   'caraway seeds',
#   'raisins'],
#  ['bananas',
#   'egg',
#   'low-fat buttermilk',
#   'granulated sugar',
#   'brown sugar',
#   'flour',
#   'baking soda',
#   'salt',
#   'chocolate chips',
#   'walnuts'],
#  ['ground chuck',
#   'lard',
#   'salt',
#   'onion',
#   'prepared yellow mustard',
#   'vinegar',
#   'sugar',
#   'water',
#   'salt and pepper'],
#  ['olive oil',
#   'boneless beef chuck roast',
#   'onions',
#   'red wine',
#   'diced tomatoes',
#   'dried oregano',
#   'dried basil',
#   'thyme',
#   'hoisin sauce',
#   'bay leaves',
#   'garlic clove',
#   'carrot',
#   'cornstarch',
#   'water',
#   'fresh parsley'],
#  ['granulated yeast', 'bread flour', 'salt', 'sugar', 'olive oil', 'water'],
#  ['flour', 'salt', 'sugar', 'oil', 'milk'],
#  ['flour',
#   'paprika',
#   'garlic salt',
#   'black pepper',
#   'cayenne pepper',
#   'butter',
#   'chicken wings'],
#  ['ground beef',
#   'egg',
#   'dry breadcrumbs',
#   'dry onion soup mix',
#   'worcestershire sauce',
#   'pepper',
#   'water',
#   'flour'],
#  ['potatoes',
#   'onion',
#   'chicken broth',
#   'condensed cream of chicken soup',
#   'cream cheese',
#   'bacon',
#   'chives'],
#  ['ground beef',
#   'taco seasoning',
#   'refried beans',
#   'monterey jack cheese',
#   'salsa',
#   'green onions',
#   'black olives',
#   'tomatoes',
#   'corn chips'],
#  ['butternut squash',
#   'unsalted butter',
#   'light brown sugar',
#   'kosher salt',
#   'fresh ground black pepper'],
#  ['brussels sprouts',
#   'butter',
#   'olive oil',
#   'garlic',
#   'parmesan cheese',
#   'salt and pepper'],
#  ['yeast', 'sugar', 'warm water', 'flour', 'salt', 'rosemary', 'butter'],
#  ['brown sugar',
#   'all-purpose flour',
#   'unsalted butter',
#   'cinnamon',
#   'vegetable oil',
#   'egg',
#   'vanilla',
#   'baking soda',
#   'salt',
#   'buttermilk',
#   'tart apples'],
#  ['cream of chicken soup',
#   'salsa',
#   'water',
#   'whole kernel corn',
#   'long-grain white rice',
#   'boneless chicken breast halves',
#   'chili powder',
#   'shredded cheddar cheese',
#   'canned black beans'],
#  ['fresh jalapeno peppers',
#   'cream cheese',
#   'shredded cheddar cheese',
#   'bacon'],
#  ['oatmeal', 'cottage cheese', 'vanilla', 'egg whites'],
#  ['flour',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'cinnamon',
#   'butter',
#   'sugar',
#   'light brown sugar',
#   'eggs',
#   'sour cream',
#   'vanilla',
#   'strawberries',
#   'walnuts'],
#  ['butter',
#   'whole grain mustard',
#   'honey',
#   'dry breadcrumbs',
#   'walnuts',
#   'fresh parsley',
#   'salmon fillets',
#   'black pepper',
#   'kosher salt',
#   'limes'],
#  ['whole chickens',
#   'water',
#   'poultry seasoning',
#   'garlic powder',
#   'black pepper',
#   'red pepper',
#   'celery ribs',
#   'green onions',
#   'carrot',
#   'chicken bouillon cubes',
#   'flour',
#   'baking powder',
#   'salt',
#   'margarine',
#   'eggs',
#   'chicken stock'],
#  ['eggs',
#   'all-purpose flour',
#   'sugar',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'buttermilk',
#   'unsalted butter',
#   'vanilla extract',
#   'vegetable oil',
#   'maple syrup'],
#  ['pork chops',
#   'onions',
#   'celery ribs',
#   'green pepper',
#   'stewed tomatoes',
#   'ketchup',
#   'cider vinegar',
#   'brown sugar',
#   'worcestershire sauce',
#   'lemon juice',
#   'beef bouillon cube',
#   'cornstarch',
#   'water'],
#  ['bread', 'american cheese', 'mayonnaise'],
#  ['jumbo shrimp',
#   'olive oil',
#   'garlic',
#   'salt and pepper',
#   'unseasoned breadcrumbs',
#   'parmesan cheese',
#   'butter',
#   'lemon'],
#  ['boneless skinless chicken breast halves',
#   'chive & onion cream cheese',
#   'butter',
#   'salt',
#   'bacon'],
#  ['ground beef',
#   'tomatoes',
#   'onion',
#   'bell pepper',
#   'celery',
#   'mushrooms',
#   'brown sugar',
#   'worcestershire sauce',
#   'cream of mushroom soup',
#   'sharp cheddar cheese',
#   'angel hair pasta',
#   'tomato sauce',
#   'salt and pepper'],
#  ['cream cheese',
#   'powdered sugar',
#   'pumpkin pie filling',
#   'ground cinnamon',
#   'ground ginger',
#   'apple',
#   'gingersnaps'],
#  ['sugar',
#   'salt',
#   'flour',
#   'vegetable oil',
#   'eggs',
#   'vanilla',
#   'baking soda',
#   'buttermilk',
#   'pecans',
#   'bananas'],
#  ['boneless skinless chicken breasts',
#   'dijon mustard',
#   'egg',
#   'dry breadcrumbs',
#   'poultry seasoning',
#   'garlic powder',
#   'seasoning salt',
#   'olive oil',
#   'chicken broth',
#   'fresh lemon juice',
#   'salt',
#   'lemon slices',
#   'fresh parsley'],
#  ['all-purpose flour',
#   'dry mustard',
#   'salt',
#   'garlic powder',
#   'boneless pork chops',
#   'condensed chicken broth',
#   'vegetable oil'],
#  ['potatoes',
#   'bacon',
#   'celery',
#   'onion',
#   'sweet pickle relish',
#   'mayonnaise',
#   'sugar',
#   'celery seeds',
#   'apple cider vinegar',
#   'prepared mustard',
#   'salt',
#   'hardboiled egg'],
#  ['olive oil',
#   'onion',
#   'garlic clove',
#   'chicken broth',
#   'whole tomatoes',
#   'tortellini',
#   'kosher salt',
#   'cracked black pepper',
#   'fresh spinach',
#   'parmesan cheese'],
#  ['olive oil',
#   'black pepper',
#   'ground beef',
#   'onion',
#   'carrots',
#   'frozen peas',
#   'fresh thyme',
#   'flour',
#   'butter',
#   'red wine',
#   'tomato paste',
#   'worcestershire sauce',
#   'chicken stock',
#   'mashed potatoes',
#   'egg',
#   'parmesan cheese'],
#  ['flour',
#   'salt',
#   'baking powder',
#   'butter',
#   'sugar',
#   'eggs',
#   'milk',
#   'vanilla essence'],
#  ['butter',
#   'flour',
#   'salt',
#   'dry mustard',
#   'pepper',
#   'milk',
#   'cheddar cheese',
#   'elbow macaroni'],
#  ['ground turkey',
#   'feta cheese',
#   'kalamata olive',
#   'dried oregano',
#   'italian seasoning',
#   'dried parsley',
#   'dried basil',
#   'onion powder',
#   'garlic powder',
#   'ground black pepper'],
#  ['flour', 'cornstarch', 'baking soda', 'baking powder', 'salt', 'water'],
#  ['chicken wings',
#   'olive oil',
#   'soy sauce',
#   'ketchup',
#   'honey',
#   'garlic clove',
#   'salt',
#   'ground black pepper'],
#  ['vegetable oil',
#   'white onion',
#   'celery',
#   'carrot',
#   'green bell pepper',
#   'garlic',
#   'black beans',
#   'chicken stock',
#   'apple cider vinegar',
#   'chili powder',
#   'cayenne pepper',
#   'cumin',
#   'salt',
#   'hickory liquid smoke',
#   'monterey jack and cheddar cheese blend',
#   'green onion'],
#  ['flour',
#   'salt',
#   'pepper',
#   'boneless beef short ribs',
#   'butter',
#   'onion',
#   'beef broth',
#   'red wine vinegar',
#   'brown sugar',
#   'chili sauce',
#   'catsup',
#   'worcestershire sauce',
#   'garlic',
#   'chili powder'],
#  ['ground beef',
#   'onion',
#   'garlic powder',
#   'worcestershire sauce',
#   'tomato sauce',
#   'paprika',
#   'oregano',
#   'chili powder',
#   'cumin',
#   'black pepper',
#   'cheese',
#   'enchilada sauce',
#   'olive',
#   'corn tortillas',
#   'oil'],
#  ['water',
#   'ham bone',
#   'dried split green peas',
#   'carrots',
#   'onions',
#   'celery ribs',
#   'bay leaf',
#   'beef bouillon cubes',
#   'salt',
#   'black peppercorns',
#   'dried thyme'],
#  ['olive oil',
#   'onion',
#   'garlic cloves',
#   'jalapeno pepper',
#   'green pepper',
#   'boneless skinless chicken breasts',
#   'frozen corn',
#   'dry white wine',
#   'cumin',
#   'chili powder',
#   'cayenne pepper',
#   'chicken broth',
#   'diced tomatoes',
#   'tomato sauce',
#   'non-fat tortilla chips'],
#  ['condensed cream of mushroom soup',
#   'dry onion soup mix',
#   'water',
#   'pot roast'],
#  ['plain yogurt',
#   'cucumber',
#   'onions',
#   'garlic clove',
#   'sugar',
#   'lean ground beef',
#   'dried oregano',
#   'garlic powder',
#   'onion powder',
#   'salt',
#   'pepper',
#   'pita breads',
#   'lettuce',
#   'tomatoes',
#   'onion'],
#  ['milk',
#   'egg',
#   'butter',
#   'white sugar',
#   'salt',
#   'bread flour',
#   'active dry yeast'],
#  ['butter',
#   'flour',
#   'red chili powder',
#   'cumin',
#   'garlic powder',
#   'tomato paste',
#   'water',
#   'salt and pepper'],
#  ['sugar', 'cocoa', 'cornstarch', 'salt', 'skim milk', 'vanilla extract'],
#  ['sugar',
#   'brown sugar',
#   'butter',
#   'egg',
#   'vanilla extract',
#   'cinnamon',
#   'baking soda',
#   'salt',
#   'all-purpose flour',
#   'quick-cooking oats',
#   'dried cranberries',
#   'white chocolate chips'],
#  ['butter',
#   'sugar',
#   'water',
#   'semi-sweet chocolate chips',
#   'vanilla',
#   'eggs',
#   'flour',
#   'baking soda',
#   'salt'],
#  ['butter',
#   'sugar',
#   'light brown sugar',
#   'eggs',
#   'vanilla',
#   'flour',
#   'baking soda',
#   'instant vanilla pudding',
#   'milk chocolate chips',
#   'walnuts'],
#  ['chicken broth',
#   'tomato sauce',
#   'diced tomatoes',
#   'cooked chicken',
#   'anaheim chilies',
#   'jalapeno pepper',
#   'diced onion',
#   'tomatoes',
#   'garlic cloves',
#   'cilantro',
#   'chili powder',
#   'cumin',
#   'pepper',
#   'salt',
#   'tabasco sauce',
#   'chipotle pepper',
#   'shredded cheddar cheese',
#   'avocado',
#   'lime',
#   'tortilla chips'],
#  ['pesto sauce mix',
#   'boneless skinless chicken breasts',
#   'breadcrumbs',
#   'provolone cheese',
#   'mushrooms'],
#  ['cooked brown rice',
#   'black beans',
#   'corn',
#   'fresh tomatoes',
#   'red onion',
#   'cilantro',
#   'jalapeno pepper',
#   'fresh lime juice',
#   'olive oil',
#   'salt',
#   'fresh ground pepper',
#   'hot sauce'],
#  ['parmesan cheese',
#   'italian seasoned breadcrumbs',
#   'paprika',
#   'dried parsley',
#   'garlic powder',
#   'fresh ground pepper',
#   'boneless skinless chicken breast'],
#  ['granulated sugar',
#   'salt',
#   'ground cinnamon',
#   'ground ginger',
#   'ground cloves',
#   'eggs',
#   'pumpkin puree',
#   'carnation evaporated milk',
#   'unbaked 9-inch deep dish pie pastry',
#   'whipped cream'],
#  ['margarine',
#   'garlic',
#   'garlic powder',
#   'black pepper',
#   'parmesan cheese',
#   'cheddar cheese'],
#  ['pie crusts',
#   'whole milk',
#   'white sugar',
#   'all-purpose flour',
#   'salt',
#   'egg yolks',
#   'butter',
#   'vanilla',
#   'bananas'],
#  ['french onion soup',
#   'ground beef',
#   'dry breadcrumbs',
#   'egg',
#   'salt',
#   'ground black pepper',
#   'all-purpose flour',
#   'ketchup',
#   'worcestershire sauce',
#   'mustard powder',
#   'water'],
#  ['fresh strawberries',
#   'sugar',
#   'cream cheese',
#   'powdered sugar',
#   'frozen whipped topping',
#   'angel food cake'],
#  ['butter',
#   'sugar',
#   'brown sugar',
#   'canned pumpkin',
#   'egg',
#   'vanilla extract',
#   'flour',
#   'baking soda',
#   'baking powder',
#   'cinnamon',
#   'ground nutmeg',
#   'salt',
#   'dark brown sugar',
#   'milk',
#   "confectioners' sugar"],
#  ['corn oil', 'vegetable shortening', 'all-purpose flour'],
#  ['mayonnaise',
#   'jalapenos',
#   'jalapeno juice',
#   'sugar',
#   'cumin',
#   'paprika',
#   'cayenne pepper',
#   'garlic powder',
#   'salt',
#   'flour tortillas',
#   'chicken tenderloins',
#   'cheddar cheese',
#   'monterey jack cheese',
#   'process american cheese'],
#  ['peach slices',
#   'pineapple chunks',
#   'vanilla instant pudding mix',
#   'strawberry',
#   'banana',
#   'blueberries',
#   'grapes',
#   'sugar'],
#  ['stewed tomatoes',
#   'chicken stock',
#   'rice',
#   'butter',
#   'chili powder',
#   'oregano',
#   'garlic salt',
#   'cumin'],
#  ['butter', 'all-purpose flour', 'black pepper', 'pan drippings'],
#  ['salt',
#   'paprika',
#   'onion powder',
#   'dry mustard',
#   'garlic powder',
#   'pepper',
#   'cumin',
#   'basil',
#   'italian seasoning',
#   'tilapia fillets',
#   'breadcrumbs',
#   'green onions',
#   'dried parsley flakes',
#   'olive oil'],
#  ['flour',
#   'sugar',
#   'baking soda',
#   'salt',
#   'eggs',
#   'vegetable oil',
#   'vanilla',
#   'apples',
#   'apple juice',
#   'walnuts',
#   'brown sugar',
#   'butter',
#   'whipping cream'],
#  ['graham cracker crumbs',
#   'butter',
#   'sugar',
#   'cream cheese',
#   'vanilla',
#   'canned pumpkin',
#   'eggs',
#   'cinnamon',
#   'nutmeg',
#   'allspice',
#   'whipped cream'],
#  ['green cabbage',
#   'carrot',
#   'green onions',
#   'celery seeds',
#   'mayonnaise',
#   'whole milk',
#   'buttermilk',
#   'white vinegar',
#   'fresh lemon juice',
#   'white sugar',
#   'garlic powder',
#   'seasoning salt',
#   'fresh ground black pepper'],
#  ['poblano pepper',
#   'reynolds wrap foil',
#   'olive oil',
#   'green onions',
#   'garlic cloves',
#   'ground beef',
#   'taco seasoning mix',
#   'cayenne pepper',
#   'canned black beans',
#   'corn kernel',
#   'cream cheese',
#   'chicken stock',
#   'chives',
#   'fresh cilantro',
#   'salt and pepper',
#   'corn tortillas',
#   'sharp cheddar cheese',
#   'monterey jack cheese',
#   'sour cream',
#   'green onion',
#   'black olives',
#   'jalapeno'],
#  ['bacon',
#   'onion',
#   'baby clams',
#   'potatoes',
#   'cream of celery soup',
#   'heavy cream',
#   'milk',
#   'butter',
#   'dried dill weed'],
#  ['corn on the cob', 'water'],
#  ['butter',
#   'cream cheese',
#   'heavy cream',
#   'garlic powder',
#   'salt & freshly ground black pepper',
#   'parmesan cheese'],
#  ['chicken broth',
#   'lentils',
#   'brown rice',
#   'onion',
#   'italian seasoning',
#   'garlic powder',
#   'cheese'],
#  ['head romaine lettuce',
#   'garlic-flavored croutons',
#   'parmesan cheese',
#   'black pepper',
#   'anchovy fillets',
#   'fresh garlic cloves',
#   'mayonnaise',
#   'half-and-half cream',
#   'lemon juice',
#   'dijon mustard',
#   'salt and pepper',
#   'worcestershire sauce',
#   'buttermilk'],
#  ['pork shoulder butt', 'pepsi', 'cream of mushroom soup', 'onion soup mix'],
#  ['eggs',
#   'vegetable oil',
#   'vanilla',
#   'white sugar',
#   'flour',
#   'baking powder',
#   'salt'],
#  ['whole turkey',
#   'olive oil',
#   'seasoning salt',
#   'poultry seasoning',
#   'pepper'],
#  ['baking potatoes',
#   'parmesan cheese',
#   'oil',
#   'salt',
#   'garlic powder',
#   'paprika',
#   'black pepper'],
#  ['potatoes',
#   'kielbasa',
#   'onion',
#   'green pepper',
#   'vegetable oil',
#   'oregano',
#   'basil',
#   'salt',
#   'pepper',
#   'water',
#   'american cheese'],
#  ['white sugar',
#   'brown sugar',
#   'butter',
#   'vanilla',
#   'eggs',
#   'all-purpose flour',
#   'baking soda',
#   'salt',
#   'semi-sweet chocolate chips',
#   'walnuts'],
#  ['cooked chicken',
#   'celery',
#   'seedless grapes',
#   'walnuts',
#   'onion',
#   'salt',
#   'worcestershire sauce',
#   'miracle whip'],
#  ['garlic clove',
#   'onion',
#   'chopped tomato',
#   'green onion',
#   'chili powder',
#   'cumin powder',
#   'tomato sauce',
#   'black beans',
#   'cilantro',
#   'salt and pepper',
#   'corn tortillas',
#   'low-fat cheddar cheese'],
#  ['all-purpose flour',
#   'baking soda',
#   'salt',
#   'real butter',
#   'shortening',
#   'brown sugar',
#   'vanilla',
#   'eggs',
#   'semi-sweet chocolate chips',
#   'nuts'],
#  ['sugar',
#   'corn syrup',
#   'eggs',
#   'butter',
#   'vanilla',
#   'pecans',
#   'deep dish pie shell'],
#  ['yeast', 'water', 'flour', 'olive oil', 'sugar', 'salt'],
#  ['boneless skinless chicken breasts',
#   'olive oil',
#   'garlic cloves',
#   'pepper',
#   'breadcrumbs',
#   'cayenne pepper'],
#  ['frozen corn', 'salt', 'butter', 'sugar', 'water', 'cornstarch'],
#  ['hamburger',
#   'onions',
#   'garlic',
#   'salt',
#   'pepper',
#   'sugar',
#   'tomato sauce',
#   'cream cheese',
#   'sour cream',
#   'shredded cheddar cheese',
#   'noodles'],
#  ['flour',
#   'granulated sugar',
#   'baking soda',
#   'salt',
#   'cocoa powder',
#   'oil',
#   'water',
#   'vanilla extract',
#   'vinegar'],
#  ['all-purpose flour',
#   'sugar',
#   'baking powder',
#   'salt',
#   'shortening',
#   'milk',
#   'vanilla',
#   'eggs'],
#  ['tomatoes and green chilies',
#   'whole canned tomatoes',
#   'jalapenos',
#   'yellow onion',
#   'garlic salt',
#   'cumin',
#   'sugar'],
#  ['active dry yeast',
#   'water',
#   'warm water',
#   'vegetable oil',
#   'sugar',
#   'egg',
#   'salt',
#   'flour'],
#  ['potatoes',
#   'cooking oil',
#   'parmesan cheese',
#   'salt',
#   'paprika',
#   'pepper',
#   'garlic powder'],
#  ['cake flour',
#   'sugar',
#   'egg whites',
#   'cream of tartar',
#   'salt',
#   'vanilla',
#   'almond extract'],
#  ['soy sauce',
#   'chicken broth',
#   'rice wine',
#   'sugar',
#   'sesame oil',
#   'white pepper',
#   'cooking oil',
#   'garlic',
#   'minced ginger',
#   'cornstarch',
#   'water'],
#  ['margarine',
#   'flour',
#   'onion',
#   'salt',
#   'pepper',
#   'chicken broth',
#   'milk',
#   'cooked chicken',
#   'frozen mixed vegetables',
#   'pie crusts'],
#  ['onion',
#   'garlic cloves',
#   'celery ribs',
#   'red bell pepper',
#   'chicken bouillon cubes',
#   'boiling water',
#   'black beans',
#   'salt',
#   'cumin',
#   'lemon, juice of',
#   'cornstarch'],
#  ['reynolds wrap foil',
#   'bacon',
#   'flakey biscuits',
#   'mayonnaise',
#   'cream cheese',
#   'dried rosemary',
#   'salt',
#   'pepper',
#   'grape tomatoes',
#   'diced onion',
#   'monterey jack cheese'],
#  ['ground ginger',
#   'garlic powder',
#   'reduced sodium soy sauce',
#   'orange juice',
#   'honey',
#   'green onion',
#   'salmon fillets'],
#  ['roma tomatoes',
#   'garlic',
#   'olive oil',
#   'balsamic vinegar',
#   'fresh basil',
#   'kosher salt',
#   'fresh cracked pepper',
#   'italian bread',
#   'parmigiano-reggiano cheese'],
#  ['chicken thighs',
#   'soy sauce',
#   'green onion',
#   'sesame oil',
#   'honey',
#   'garlic',
#   'ground ginger',
#   'black pepper'],
#  ['dry breadcrumbs',
#   'parmesan cheese',
#   'yellow cornmeal',
#   'italian seasoning',
#   'chicken thighs',
#   'ranch salad dressing',
#   'seasoning salt'],
#  ['butter',
#   'onion',
#   'garlic clove',
#   'celery',
#   'chicken broth',
#   'broccoli',
#   'flour',
#   'milk',
#   'pepper',
#   'velveeta cheese'],
#  ['pasta',
#   'butter',
#   'shrimp',
#   'garlic',
#   'half-and-half',
#   'fresh basil',
#   'parmesan cheese',
#   'black pepper',
#   'red pepper flakes'],
#  ['bananas',
#   'white sugar',
#   'egg',
#   'baking soda',
#   'baking powder',
#   'all-purpose flour',
#   'butter',
#   'salt',
#   'nuts',
#   'chocolate chips'],
#  ['chicken breasts',
#   'sour cream',
#   'ritz crackers',
#   'sweet butter',
#   'parmesan cheese',
#   'tarragon'],
#  ['whole boneless chicken breasts',
#   'light soy sauce',
#   'cooking wine',
#   'sesame oil',
#   'flour',
#   'cornstarch',
#   'water',
#   'baking powder',
#   'baking soda',
#   'vegetable oil',
#   'chicken broth',
#   'white vinegar',
#   'sugar',
#   'dark soy sauce',
#   'chili paste',
#   'garlic clove',
#   'peanut oil',
#   'toasted sesame seeds'],
#  ['salmon fillet',
#   'sour cream',
#   'prepared mustard',
#   'onions',
#   'dried dill weed',
#   'mayonnaise',
#   'parmesan cheese',
#   'cheddar cheese',
#   'paprika'],
#  ['all-purpose flour',
#   'baking soda',
#   'salt',
#   'butter',
#   'granulated sugar',
#   'brown sugar',
#   'vanilla extract',
#   'eggs',
#   'semi-sweet chocolate chips',
#   'nuts'],
#  ['fresh gingerroot',
#   'garlic',
#   'crushed red pepper flakes',
#   'boneless skinless chicken breasts',
#   'flour',
#   'salt and pepper',
#   'olive oil',
#   'soy sauce',
#   'brown sugar',
#   'white wine vinegar',
#   'fish sauce',
#   'sugar snap pea'],
#  ['fresh strawberries',
#   'sugar',
#   'vegetable oil',
#   'eggs',
#   'gold medal all-purpose flour',
#   'baking soda',
#   'salt',
#   'cinnamon'],
#  ["wyler's chicken bouillon cubes", 'water', 'real butter', 'egg noodles'],
#  ['cod fish fillet',
#   'butter',
#   'lemon juice',
#   'all-purpose flour',
#   'salt',
#   'white pepper',
#   'paprika'],
#  ['lean ground beef',
#   'white bread',
#   'eggs',
#   'garlic powder',
#   'italian seasoning',
#   'parsley flakes',
#   'parmesan cheese',
#   'salt',
#   'black pepper',
#   'olive oil'],
#  ['butter',
#   'canola oil',
#   'green cabbage',
#   'brown sugar',
#   'garlic cloves',
#   'red wine vinegar',
#   'salt',
#   'fresh ground black pepper'],
#  ['cream cheese',
#   'eggs',
#   'heavy cream',
#   'parmesan cheese',
#   'chives',
#   'italian seasoning',
#   'garlic',
#   'mozzarella cheese',
#   'pizza sauce',
#   'pizza toppings'],
#  ['breadcrumbs',
#   'parmesan cheese',
#   'fresh parsley',
#   'salt',
#   'fresh ground pepper',
#   'butter',
#   'garlic cloves',
#   'chicken'],
#  ['italian salad dressing mix',
#   'brown sugar',
#   'oil',
#   'soy sauce',
#   'cinnamon',
#   'thyme',
#   'ground red pepper',
#   'chicken pieces'],
#  ['unsalted butter',
#   'granulated sugar',
#   'salt',
#   'pure vanilla extract',
#   'egg yolk',
#   'all-purpose flour'],
#  ['cream of chicken soup',
#   'mayonnaise',
#   'milk',
#   'yellow onion',
#   'celery',
#   'albacore tuna',
#   'cooked egg noodles',
#   'shredded cheddar cheese',
#   'salt and pepper'],
#  ['chicken wings',
#   'cayenne pepper',
#   'crushed red pepper flakes',
#   'salt',
#   'louisiana hot sauce',
#   'margarine'],
#  ['shortening',
#   'sugar',
#   'eggs',
#   'red food coloring',
#   'cocoa',
#   'buttermilk',
#   'cake flour',
#   'salt',
#   'vanilla',
#   'baking soda',
#   'vinegar',
#   'flour',
#   'milk',
#   'butter'],
#  ['zucchini',
#   'lean ground beef',
#   'onion',
#   'tomatoes',
#   'tomato paste',
#   'garlic clove',
#   'dried oregano',
#   'dried basil',
#   'dried thyme',
#   'water',
#   'pepper',
#   'egg',
#   'low fat cottage cheese',
#   'mozzarella cheese',
#   'flour'],
#  ['extra virgin olive oil',
#   'boneless skinless chicken thighs',
#   'andouille sausage',
#   'onion',
#   'celery ribs',
#   'green bell pepper',
#   'red bell pepper',
#   'dried thyme',
#   'dried oregano',
#   'sweet paprika',
#   'salt',
#   'cayenne pepper',
#   'long grain rice',
#   'tomatoes',
#   'chicken broth',
#   'medium shrimp',
#   'fresh parsley',
#   'green onions'],
#  ['shortening',
#   'butter',
#   '18% table cream',
#   'salt',
#   'almond extract',
#   'vanilla',
#   "confectioners' sugar",
#   'food coloring'],
#  ['mild chili powder',
#   'garlic powder',
#   'onion powder',
#   'dried oregano',
#   'paprika',
#   'cumin',
#   'seasoning salt',
#   'black pepper',
#   'cayenne pepper'],
#  ['egg', 'white vinegar', 'water', 'salt and pepper'],
#  ['flour',
#   'sugar',
#   'baking powder',
#   'salt',
#   'butter',
#   'milk',
#   'brown sugar',
#   'cinnamon',
#   'powdered sugar'],
#  ['boneless skinless chicken breasts',
#   'flour',
#   'onions',
#   'garlic cloves',
#   'extra virgin olive oil',
#   'fresh gingerroot',
#   'dried apricots',
#   'tomato paste',
#   'chopped tomatoes',
#   'chickpeas',
#   'honey',
#   'chicken stock',
#   'saffron',
#   'ras el hanout spice mix',
#   'ground coriander',
#   'ground cinnamon',
#   'ground cumin',
#   'cayenne pepper',
#   'salt and black pepper',
#   'fresh coriander',
#   'carrots',
#   'preserved lemon',
#   'harissa'],
#  ['refrigerated crescent dinner rolls',
#   'sugar',
#   'ground cinnamon',
#   'powdered sugar',
#   'milk',
#   'vanilla'],
#  ['milk',
#   'warm water',
#   'active dry yeast',
#   'eggs',
#   'white sugar',
#   'salt',
#   'unsalted butter',
#   'raisins',
#   'all-purpose flour',
#   'ground cinnamon',
#   'butter'],
#  ['unsalted butter',
#   'chunky peanut butter',
#   'sugar',
#   'dark brown sugar',
#   'egg',
#   'vanilla',
#   'all-purpose flour',
#   'baking soda',
#   'bittersweet chocolate chips'],
#  ['water', 'salt', 'pepper', 'vegetable oil', 'broccoli'],
#  ['ketchup',
#   'soy sauce',
#   'white vinegar',
#   'brown sugar',
#   'white sugar',
#   'cold water',
#   'cornstarch',
#   'all-purpose flour',
#   'baking powder',
#   'baking soda',
#   'garlic powder',
#   'sugar',
#   'sesame oil',
#   'oil',
#   'chicken breasts',
#   'seasoning salt'],
#  ['unsalted butter',
#   'sugar',
#   'eggs',
#   'self rising flour',
#   'all-purpose flour',
#   'milk',
#   'vanilla',
#   "confectioners' sugar"],
#  ['bread', 'tomatoes', 'miracle whip', 'salt'],
#  ['carrots', 'brown sugar', 'butter', 'ground ginger'],
#  ['butter',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'flour',
#   'cocoa',
#   'baking soda',
#   'salt',
#   'chocolate chips'],
#  ['beef ravioli',
#   'pasta sauce',
#   'tomato sauce',
#   'water',
#   'red peppers',
#   'italian spices',
#   'mozzarella cheese'],
#  ['potatoes',
#   'celery',
#   'onion',
#   'carrot',
#   'ham',
#   'water',
#   'chicken bouillon granules',
#   'salt',
#   'pepper',
#   'butter',
#   'flour',
#   'milk',
#   'cheddar cheese'],
#  ['eggs',
#   'milk',
#   'vegetable oil',
#   'all-purpose flour',
#   'baking powder',
#   'sugar',
#   'salt',
#   'vanilla',
#   'maple extract'],
#  ['butter',
#   'cream cheese',
#   'heavy cream',
#   'garlic powder',
#   'salt',
#   'black pepper',
#   'parmesan cheese',
#   'fettuccine'],
#  ['whole turkey',
#   'salt',
#   'pepper',
#   'garlic powder',
#   'water',
#   'extra virgin olive oil'],
#  ['margarine',
#   'brown sugar',
#   'granulated sugar',
#   'eggs',
#   'vanilla',
#   'all-purpose flour',
#   'baking soda',
#   'cinnamon',
#   'salt',
#   'quicker quaker oats',
#   'raisins'],
#  ['water-packed artichoke hearts',
#   'parmesan cheese',
#   'mayonnaise',
#   'garlic powder',
#   'boneless skinless chicken breast halves'],
#  ['pecans',
#   'yellow cake mix',
#   'vanilla instant pudding mix',
#   'eggs',
#   'cold water',
#   'cooking oil',
#   'dark rum',
#   'butter',
#   'water',
#   'sugar'],
#  ['all-purpose flour',
#   'white sugar',
#   'salt',
#   'baking powder',
#   'vegetable oil',
#   'egg',
#   'milk',
#   'fresh blueberries',
#   'butter',
#   'ground cinnamon'],
#  ['bisquick', 'milk', 'cheddar cheese', 'butter', 'garlic powder'],
#  ['tilapia fillets',
#   'garlic cloves',
#   'olive oil',
#   'salt and pepper',
#   'lemon',
#   'parsley'],
#  ['shortening',
#   'butter',
#   'sugar',
#   'brown sugar',
#   'eggs',
#   'vanilla',
#   'flour',
#   'baking soda',
#   'salt',
#   'chocolate chips'],
#  ['skinless chicken thighs',
#   'salt and pepper',
#   'shallot',
#   'balsamic vinegar',
#   'cooking spray'],
#  ['flank steaks',
#   'cornstarch',
#   'water',
#   'eggs',
#   'carrot',
#   'green onions',
#   'fresh ginger',
#   'garlic cloves',
#   'canola oil',
#   'soy sauce',
#   'rice vinegar',
#   'sesame oil',
#   'sugar',
#   'crushed red pepper flakes'],
#  ['chili powder',
#   'ground coriander',
#   'ground cumin',
#   'garlic powder',
#   'oregano',
#   'cayenne pepper',
#   'ground beef',
#   'onion',
#   'diced tomatoes',
#   'tomato sauce',
#   'kidney beans'],
#  ['lean ground beef',
#   'garlic',
#   'onion',
#   'worcestershire sauce',
#   'paprika',
#   'mexican oregano',
#   'chili powder',
#   'cumin',
#   'black pepper',
#   'tomatoes',
#   'cheddar cheese',
#   'flour tortillas',
#   'refried beans',
#   'enchilada sauce',
#   'beef gravy',
#   'sour cream',
#   'salsa',
#   'jalapeno',
#   'lettuce',
#   'chopped tomato'],
#  ['water', 'flour', 'salt', 'dry yeast'],
#  ['brown sugar',
#   'ketchup',
#   'lean ground beef',
#   'milk',
#   'eggs',
#   'salt',
#   'ground black pepper',
#   'onion',
#   'ground ginger',
#   'saltine crumbs'],
#  ['butter',
#   'sugar',
#   'vanilla',
#   'eggs',
#   'bananas',
#   'milk',
#   'flour',
#   'salt',
#   'baking soda',
#   'pecans'],
#  ['tomatoes',
#   'tomato puree',
#   'tomato paste',
#   'sugar',
#   'salt',
#   'black pepper',
#   'italian seasoning',
#   'garlic powder',
#   'parsley',
#   'parmesan cheese',
#   'onions',
#   'garlic',
#   'italian sausage',
#   'spareribs',
#   'chicken thighs',
#   'pepperoni'],
#  ['shredded cheddar cheese',
#   'chicken meat',
#   'zucchini',
#   'eggs',
#   'baking mix',
#   'salt',
#   'garlic powder',
#   'dried onion flakes',
#   'fresh parsley',
#   'milk',
#   'olive oil',
#   'paprika'],
#  ['beef stew meat',
#   'flour',
#   'salt',
#   'pepper',
#   'vegetable oil',
#   'onion',
#   'carrot',
#   'celery',
#   'dried parsley',
#   'thyme',
#   'beef broth',
#   'potatoes',
#   'carrots',
#   'onions'],
#  ['lean ground beef',
#   'chorizo sausage',
#   'egg',
#   'garlic cloves',
#   'carrot',
#   'cooked rice',
#   'cilantro leaf',
#   'salt',
#   'pepper',
#   'ground cumin',
#   'chicken broth',
#   'onion',
#   'celery',
#   'diced tomatoes',
#   'oregano',
#   'cilantro',
#   'zucchini'],
#  ['summer squash', 'butter', 'onion', 'salt & pepper'],
#  ['flour', 'shortening', 'salt', 'egg', 'cold water', 'vinegar'],
#  ['potatoes',
#   'garlic',
#   'olive oil',
#   'sour cream',
#   'butter',
#   'milk',
#   'salt',
#   'white pepper'],
#  ['diced tomatoes',
#   'corn',
#   'minestrone soup',
#   'mixed vegetables',
#   'black beans'],
#  ['cauliflower',
#   'sour cream',
#   'shredded cheddar cheese',
#   'green onions',
#   'cooked bacon',
#   'salt and pepper'],
#  ['ground beef',
#   'onion',
#   'garlic clove',
#   'pace picante sauce',
#   'ground cumin',
#   'dried oregano leaves',
#   'salt',
#   'flour tortillas',
#   'butter'],
#  ['butter',
#   'sugar',
#   'egg',
#   'all-purpose flour',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'buttermilk',
#   'ground cinnamon'],
#  ['all-purpose flour',
#   'egg',
#   'buttermilk',
#   'granulated sugar',
#   'baking powder',
#   'baking soda',
#   'cooking oil',
#   'salt'],
#  ['country-style pork ribs',
#   'dr. pepper cola',
#   'garlic cloves',
#   'liquid smoke',
#   'onion',
#   'barbecue sauce'],
#  ['chex cereal',
#   'semi-sweet chocolate chips',
#   'smooth peanut butter',
#   'butter',
#   'vanilla',
#   'powdered sugar'],
#  ['chili powder',
#   'flour',
#   'cocoa powder',
#   'garlic salt',
#   'oregano',
#   'water',
#   'tomato sauce'],
#  ['spice cake mix', 'pumpkin', 'water'],
#  ['bisquick baking mix',
#   'butter',
#   'sharp cheddar cheese',
#   'whole milk',
#   'garlic powder',
#   'dried parsley flakes',
#   'salt'],
#  ['canned salmon', 'onion', 'cornmeal', 'flour', 'egg', 'mayonnaise'],
#  ['pork loin',
#   'salt and pepper',
#   'honey',
#   'orange juice',
#   'olive oil',
#   'thyme',
#   'chicken broth'],
#  ['sugar',
#   'all-purpose flour',
#   'salt',
#   'milk',
#   'egg yolks',
#   'butter',
#   'vanilla extract',
#   'firm bananas',
#   'pie shells',
#   'whipped cream',
#   'banana'],
#  ['cornstarch',
#   'chili powder',
#   'salt',
#   'paprika',
#   'sugar',
#   'chicken bouillon cube',
#   'onion powder',
#   'garlic powder',
#   'cayenne pepper',
#   'cumin'],
#  ['shrimp',
#   'butter',
#   'garlic',
#   'dried oregano',
#   'dried basil',
#   'dried thyme',
#   'cayenne pepper',
#   'crushed red pepper flakes',
#   'salt',
#   'black pepper',
#   'beer'],
#  ['egg',
#   'vegetable oil',
#   'milk',
#   'flour',
#   'salt',
#   'baking powder',
#   'sweet onions',
#   'oil'],
#  ['butter',
#   'granulated sugar',
#   'brown sugar',
#   'vanilla',
#   'eggs',
#   'flour',
#   'baking soda',
# ...
#   'bay leaves'],
#  ['garlic',
#   'yellow onion',
#   'butter',
#   'dry white wine',
#   'fresh lemon juice',
#   'sun-dried tomatoes',
#   'fresh basil',
#   'kosher salt',
#   'white pepper',
#   'boneless skinless chicken breast halves',
#   'extra virgin olive oil',
#   'salt',
#   'black pepper',
#   'goat cheese'],
#  ['simply potatoes diced potatoes with onion',
#   'bacon',
#   'eggs',
#   'red bell pepper',
#   'green onion',
#   'feta',
#   'shredded cheddar cheese',
#   'salt',
#   'pepper',
#   'paprika',
#   'jalapeno',
#   'onion powder',
#   'corn beef hash',
#   'olive oil',
#   'garlic clove'],
#  ['vegan mayonnaise',
#   'garlic powder',
#   'onion powder',
#   'black pepper',
#   'parsley',
#   'unsweetened soymilk'],
#  ['eggs', 'banana', 'cooking spray'],
#  ['vegetable oil',
#   'pork chops',
#   'onions',
#   'garlic cloves',
#   'dry mustard',
#   'salt',
#   'fresh ground black pepper',
#   'cayenne pepper',
#   'all-purpose flour',
#   'cider vinegar',
#   'white wine',
#   'dijon mustard',
#   'whipping cream'],
#  ['ground beef',
#   'onion',
#   'garlic clove',
#   'mozzarella cheese',
#   'italian style breadcrumbs',
#   'fresh parsley',
#   'egg',
#   'spaghetti sauce',
#   'tomato sauce',
#   'parmesan cheese',
#   'jumbo pasta shells',
#   'salt and pepper',
#   'dry red wine'],
#  ['canned black beans',
#   'canned corn',
#   'red onion',
#   'fresh cilantro',
#   'lime juice',
#   'olive oil',
#   'salt',
#   'ground cumin',
#   'ground red pepper'],
#  ['boneless chicken breast',
#   'olive oil',
#   'ground paprika',
#   'garlic cloves',
#   'fresh ginger',
#   'salt',
#   'pepper',
#   'cayenne',
#   'bell pepper',
#   'onion',
#   'tomatoes',
#   'flat bread',
#   'sour cream',
#   'cilantro',
#   'green onion',
#   'lime juice'],
#  ['french bread dough',
#   'lean ground beef',
#   'salt',
#   'pepper',
#   'part-skim mozzarella cheese',
#   'italian herb seasoning',
#   'fresh parsley',
#   'tomato sauce'],
#  ['baking potatoes',
#   'butter',
#   'skim milk',
#   'fat free cream cheese',
#   'salt',
#   'ground black pepper',
#   'sharp cheddar cheese'],
#  ['jiffy cornbread mix',
#   'whole kernel corn',
#   'creamed corn',
#   'sour cream',
#   'butter'],
#  ['light mayonnaise',
#   'lemon juice',
#   'garlic clove',
#   'dijon mustard',
#   'parmesan cheese',
#   'green onion',
#   'tabasco sauce',
#   'halibut fillet',
#   'salt',
#   'fresh ground black pepper'],
#  ['lean ground lamb',
#   'garlic',
#   'dried oregano',
#   'onion powder',
#   'salt',
#   'pepper'],
#  ['yukon gold potatoes',
#   'lemon juice',
#   'olive oil',
#   'garlic cloves',
#   'dried oregano',
#   'sea salt',
#   'fresh ground black pepper',
#   'chicken broth'],
#  ['all-purpose flour', 'cornstarch'],
#  ['boneless skinless chicken breasts',
#   'parmesan cheese',
#   'corn flakes',
#   'ranch dressing mix',
#   'butter'],
#  ['robin hood oats',
#   'all-purpose flour',
#   'granulated sugar',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'egg',
#   'bananas',
#   'butter',
#   'nuts'],
#  ['water',
#   'egg',
#   'all-purpose flour',
#   'whole wheat flour',
#   'salt',
#   'shortening',
#   'sugar',
#   'yeast',
#   'vital wheat gluten'],
#  ['reduced fat graham cracker crust',
#   'sugar-free lime gelatin',
#   'boiling water',
#   'fat-free whipped topping',
#   'key lime pie yogurt'],
#  ['all-purpose flour',
#   'salt',
#   'black pepper',
#   'cayenne pepper',
#   'paprika',
#   'egg',
#   'milk',
#   'chicken breast fillets',
#   'vegetable oil',
#   'hot sauce',
#   'margarine',
#   'bleu cheese salad dressing',
#   'celery rib'],
#  ['pretzel twists', 'rollo candies', 'whole pecans'],
#  ['baking cocoa',
#   'baking powder',
#   'butter',
#   'boiling water',
#   'vanilla',
#   'sugar',
#   'eggs',
#   'all-purpose flour',
#   'salt',
#   'mini chocolate chip',
#   'walnuts'],
#  ['frozen black-eyed peas',
#   'bacon',
#   'onion',
#   'celery',
#   'garlic cloves',
#   'chicken broth',
#   'salt',
#   'ground black pepper'],
#  ['small red potatoes', 'vegetable oil', 'hidden valley ranch dressing mix'],
#  ['yukon gold potatoes',
#   'extra virgin olive oil',
#   'salt',
#   'pam cooking spray'],
#  ['macaroni',
#   'butter',
#   'flour',
#   '1% low-fat milk',
#   'low-fat cream cheese',
#   'salt',
#   'fresh ground black pepper',
#   'dijon mustard',
#   'sharp cheddar cheese',
#   'fresh breadcrumb',
#   'fresh parsley'],
#  ['ground beef',
#   'onion',
#   'green pepper',
#   'celery ribs',
#   'kidney beans',
#   'tomato puree',
#   'salsa',
#   'diced tomatoes',
#   'condensed beef broth',
#   'water',
#   'chili powder',
#   'worcestershire sauce',
#   'dried basil',
#   'ground cumin',
#   'steak sauce',
#   'garlic powder',
#   'salt',
#   'fresh coarse ground black pepper',
#   'browning sauce',
#   'shredded cheddar cheese'],
#  ['lean ground beef',
#   'egg',
#   'onion',
#   'carrot',
#   'green pepper',
#   'italian seasoned breadcrumbs',
#   'milk',
#   'worcestershire sauce',
#   'salt',
#   'fresh ground black pepper'],
#  ['garlic',
#   'olive oil',
#   'breadcrumbs',
#   'parmesan cheese',
#   'boneless skinless chicken breast halves'],
#  ['diced tomatoes',
#   'tomato sauce',
#   'water',
#   'diced onion',
#   'green bell pepper',
#   'garlic cloves',
#   'fresh parsley leaves',
#   'italian seasoning',
#   'seasoning salt',
#   'sugar',
#   'bay leaves',
#   'ground beef',
#   'angel hair pasta',
#   'cheddar cheese',
#   'monterey jack cheese',
#   'salt',
#   'black pepper',
#   'garlic powder'],
#  ['all-purpose flour',
#   'granulated sugar',
#   'sweet unsalted butter',
#   'egg',
#   'baking soda',
#   'pure vanilla extract',
#   'black pepper',
#   'sugar'],
#  ['pecans',
#   'oreo cookie crumbs',
#   'sugar',
#   'butter',
#   'cream cheese',
#   'eggs',
#   'baileys original irish cream',
#   'vanilla',
#   'semi-sweet chocolate chips',
#   'whipping cream',
#   'instant coffee powder',
#   'chocolate curls'],
#  ['cherries',
#   'sugar',
#   'flour',
#   'cinnamon',
#   'pastry for a double-crust 9-inch pie'],
#  ['basmati rice',
#   'chicken stock',
#   'butter',
#   'dried onion flakes',
#   'salt',
#   'saffron'],
#  ['hot water',
#   'apple cider vinegar',
#   'sugar',
#   'fresh ground pepper',
#   'onion',
#   'corned beef brisket',
#   'white potatoes',
#   'cabbage',
#   'carrots'],
#  ['white sugar',
#   'butter',
#   'eggnog',
#   'vanilla extract',
#   'egg yolks',
#   'ground nutmeg',
#   'all-purpose flour',
#   'baking powder',
#   'ground cinnamon'],
#  ['lamb loin chops',
#   'soy sauce',
#   'olive oil',
#   'red wine vinegar',
#   'peppercorns',
#   'dijon mustard',
#   'thyme',
#   'garlic'],
#  ['oreo cookies',
#   'roasted peanuts',
#   'butter',
#   'cream cheese',
#   'eggs',
#   'brown sugar',
#   'smooth peanut butter',
#   'whipping cream',
#   'vanilla extract',
#   "reese's peanut butter cups",
#   'sour cream',
#   'sugar'],
#  ['pork roast',
#   'garlic cloves',
#   'onion',
#   'water',
#   'kitchen bouquet',
#   'black pepper',
#   'salt',
#   'lard',
#   'cornstarch'],
#  ['old bay seasoning',
#   'salt',
#   'water',
#   'beer',
#   'red potatoes',
#   'vidalia onions',
#   'smoked sausage',
#   'corn on the cob',
#   'large shrimp'],
#  ['margarine',
#   'sugar',
#   'eggs',
#   'milk',
#   'flour',
#   'baking powder',
#   'vanilla',
#   'biscuit mix',
#   'cinnamon',
#   'powdered sugar'],
#  ['becel margarine',
#   'cocoa powder',
#   'granulated sugar',
#   'egg',
#   'unsweetened applesauce',
#   'vanilla',
#   'all-purpose flour',
#   'baking soda',
#   'salt'],
#  ['fresh mushrooms', 'butter', 'flour', 'stock', 'half-and-half cream'],
#  ['cherry pie filling', 'chocolate cake mix', 'butter'],
#  ['water', 'sugar', 'instant coffee', 'vanilla', 'vodka'],
#  ['lime juice',
#   'water',
#   'olive oil',
#   'garlic cloves',
#   'soy sauce',
#   'salt',
#   'liquid smoke',
#   'cayenne pepper',
#   'black pepper',
#   'top sirloin steaks',
#   'spanish onion',
#   'green pepper',
#   'red pepper',
#   'yellow pepper'],
#  ['eggs',
#   'garlic',
#   'fresh parsley',
#   'coarse salt',
#   'ground pepper',
#   'fresh breadcrumb',
#   'parmesan cheese',
#   'chicken cutlets',
#   'olive oil',
#   'butter',
#   'dry white wine',
#   'chicken broth',
#   'fresh lemon juice'],
#  ['jars',
#   'fresh dill',
#   'cucumber',
#   'garlic clove',
#   'water',
#   'white vinegar',
#   'pickling salt'],
#  ['onion',
#   'peanut oil',
#   'rice vinegar',
#   'water',
#   'fresh ginger',
#   'celery',
#   'ketchup',
#   'soy sauce',
#   'sugar',
#   'lemon juice',
#   'garlic',
#   'salt',
#   'pepper'],
#  ['extra virgin olive oil',
#   'garlic cloves',
#   'red pepper flakes',
#   'shrimp',
#   'salt',
#   'lemon juice',
#   'dry white wine',
#   'butter',
#   'flat leaf parsley'],
#  ['boneless skinless chicken breast halves',
#   'flour',
#   'salt and pepper',
#   'oil',
#   'chicken broth',
#   'garlic',
#   'lemon juice',
#   'butter'],
#  ['butter',
#   'flour',
#   'milk',
#   'american cheese',
#   'sharp cheddar cheese',
#   'salt',
#   'elbow macaroni'],
#  ['frozen strawberries', 'milk', 'sugar', 'banana', 'ice cubes'],
#  ['cooking spray',
#   'leek',
#   'garlic',
#   'lean ground beef',
#   'red curry paste',
#   'tomato sauce',
#   'light coconut milk',
#   'brown sugar',
#   'lime rind',
#   'fresh lime juice',
#   'fish sauce',
#   'cooked short-grain white rice'],
#  ['yams',
#   'brown sugar',
#   'salt',
#   'cinnamon',
#   'egg',
#   'butter',
#   'miniature marshmallows'],
#  ['dijonnaise mustard',
#   'panko breadcrumbs',
#   'salt',
#   'black pepper',
#   'fresh parsley',
#   'tilapia fillets',
#   'lemon wedges',
#   'vegetable oil'],
#  ['butter',
#   'pork tenderloin',
#   'onion',
#   'fresh rosemary',
#   'chicken broth',
#   'whole berry cranberry sauce',
#   'balsamic vinegar'],
#  ['seasoned dry bread crumb',
#   'parmesan cheese',
#   'garlic powder',
#   'seasoning salt',
#   'fresh ground black pepper',
#   'egg',
#   'zucchini'],
#  ['eggs',
#   'water',
#   'butter',
#   'oil',
#   'onion',
#   'garlic cloves',
#   'cooked white rice',
#   'soy sauce',
#   'sesame oil',
#   'fresh ground black pepper',
#   'green onions'],
#  ['chicken thighs',
#   'flour',
#   'honey',
#   'soy sauce',
#   'garlic cloves',
#   'salt',
#   'pepper'],
#  ['butter',
#   'apples',
#   'brown sugar',
#   'water',
#   'cinnamon',
#   'italian bread',
#   'eggs',
#   'milk',
#   'vanilla extract'],
#  ['pork chops',
#   'salt and pepper',
#   'garlic powder',
#   'pork and beans',
#   'onion',
#   'green bell pepper',
#   'barbecue sauce',
#   'ketchup',
#   'brown sugar',
#   'cayenne pepper'],
#  ['water',
#   'chicken broth',
#   'half-and-half',
#   'salt',
#   'grits',
#   'cheddar cheese',
#   'parmesan cheese',
#   'butter',
#   'tabasco sauce',
#   'white pepper',
#   'bacon',
#   'medium shrimp',
#   'black pepper',
#   'flour',
#   'sliced mushrooms',
#   'green onion',
#   'garlic',
#   'fat-free low-sodium chicken broth',
#   'fresh lemon juice',
#   'lemon wedge'],
#  ['flour',
#   'cocoa',
#   'baking soda',
#   'salt',
#   'baking powder',
#   'margarine',
#   'white sugar',
#   'brown sugar',
#   'egg',
#   'quick-cooking oats',
#   'vanilla',
#   'chocolate chips',
#   'nuts'],
#  ['onion',
#   'green pepper',
#   'butter',
#   'cooked chicken',
#   'green chili peppers',
#   'flour',
#   'ground coriander',
#   'salt',
#   'chicken broth',
#   'sour cream',
#   'monterey jack cheese',
#   'flour tortillas'],
#  ['boneless skinless chicken breasts',
#   'lemon juice',
#   'black pepper',
#   'celery salt',
#   'paprika',
#   'condensed cream of mushroom soup',
#   'condensed cream of celery soup',
#   'dry sherry',
#   'parmesan cheese',
#   'rice'],
#  ['bread',
#   'water',
#   'brown sugar',
#   'eggs',
#   'milk',
#   'sugar',
#   'vanilla extract',
#   'cinnamon',
#   'salt'],
#  ['brussels sprout',
#   'extra virgin olive oil',
#   'garlic cloves',
#   'lemon juice',
#   'salt',
#   'white pepper'],
#  ['tomato puree',
#   'water',
#   'sugar',
#   'olive oil',
#   'lemon juice',
#   'salt',
#   'oregano',
#   'basil',
#   'thyme',
#   'garlic powder'],
#  ['potatoes',
#   'frozen peas',
#   'celery rib',
#   'green onions',
#   'cheddar cheese',
#   'hard-boiled eggs',
#   'pickle',
#   'sweet pickle relish',
#   'ranch salad dressing',
#   'mayonnaise',
#   'prepared mustard',
#   'garlic powder',
#   'salt & freshly ground black pepper'],
#  ['hardboiled egg',
#   'mayonnaise',
#   'worcestershire sauce',
#   'prepared mustard',
#   'salt',
#   'pepper',
#   'green onions',
#   'pickle relish',
#   'paprika'],
#  ['boneless skinless chicken breast halves',
#   'egg',
#   'italian seasoned breadcrumbs',
#   'margarine',
#   'spaghetti sauce',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'fresh parsley',
#   'cooked spaghetti'],
#  ['flour', 'salt', 'sugar', 'baking powder', 'milk', 'vegetable shortening'],
#  ['olive oil',
#   'onion',
#   'garlic',
#   'carrot',
#   'celery',
#   'sweet italian sausage links',
#   'dry oregano',
#   'dry basil',
#   'red pepper flakes',
#   'tomatoes with juice',
#   'vegetable stock',
#   'cannellini beans',
#   'ditalini',
#   'flat leaf parsley',
#   'parmesan cheese'],
#  ['spaghetti squash',
#   'garlic',
#   'salt',
#   'pepper',
#   'olive oil',
#   'vegetable oil',
#   'vegetables'],
#  ['ground turkey',
#   'sesame seeds',
#   'soy sauce',
#   'scallion',
#   'cilantro',
#   'garlic',
#   'sesame oil',
#   'salt',
#   'breadcrumbs',
#   'fresh ground pepper',
#   'oil'],
#  ['all-purpose flour',
#   'sugar',
#   'butter',
#   'baking powder',
#   'salt',
#   'baking soda',
#   'cinnamon',
#   'lemon zest',
#   'buttermilk',
#   'eggs',
#   'vanilla',
#   'blueberries'],
#  ['butter',
#   'flour',
#   'onion',
#   'carrot',
#   'chicken broth',
#   'smoked sausage',
#   'potato',
#   'cabbage',
#   'fresh thyme',
#   'salt and pepper'],
#  ['rump roast',
#   'garlic',
#   'black pepper',
#   'onion soup mix',
#   'bouillon',
#   'beef broth',
#   'onions'],
#  ['brown sugar',
#   'kosher salt',
#   'chili powder',
#   'pepper',
#   'cayenne pepper',
#   'old bay seasoning',
#   'thyme',
#   'onion powder',
#   'garlic powder',
#   'baby back ribs',
#   'barbecue sauce'],
#  ['margarine',
#   'miniature marshmallows',
#   'smooth peanut butter',
#   'cheerios toasted oat cereal'],
#  ['bananas',
#   'apples',
#   'lemon',
#   'pineapple tidbits',
#   'strawberries',
#   'grapes',
#   'pecans',
#   'sugar-free instant vanilla pudding mix',
#   'water'],
#  ['eggs',
#   'butter',
#   'sugar',
#   'vanilla',
#   'flour',
#   'baking powder',
#   'nuts',
#   'cranberries'],
#  ['olive oil',
#   'red pepper flakes',
#   'onion',
#   'garlic',
#   'boneless skinless chicken breasts',
#   'oregano',
#   'ground cumin',
#   'black beans',
#   'pimientos',
#   'salt & pepper',
#   'balsamic vinegar',
#   'chicken broth',
#   'white rice'],
#  ['eggs',
#   'sugar',
#   'zucchini',
#   'vegetable oil',
#   'vanilla',
#   'flour',
#   'salt',
#   'baking soda',
#   'baking powder',
#   'cinnamon',
#   'nutmeg',
#   'clove',
#   'nuts',
#   'raisins'],
#  ['tomatoes', 'bread', 'salt and pepper', 'mayonnaise'],
#  ['spaghetti',
#   'salt',
#   'water',
#   'extra virgin olive oil',
#   'garlic',
#   'dried red pepper flakes',
#   'parsley',
#   'fresh lemon juice',
#   'parmesan cheese',
#   'salt and black pepper'],
#  ['granulated sugar',
#   'all-purpose flour',
#   'cocoa',
#   'baking powder',
#   'salt',
#   'milk',
#   'butter',
#   'vanilla extract',
#   'light brown sugar',
#   'water',
#   'whipped topping'],
#  ['cocoa',
#   'all-purpose flour',
#   'sugar',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'instant coffee granules',
#   'unsweetened orange juice',
#   'eggs',
#   'vanilla',
#   'canola oil'],
#  ['chicken stock',
#   'saffron thread',
#   'butter',
#   'onion',
#   'garlic clove',
#   'risotto rice',
#   'parmesan cheese',
#   'salt and black pepper'],
#  ['green beans', 'butter', 'parmesan cheese', 'thyme'],
#  ['quinoa',
#   'water',
#   'olive oil',
#   'fresh lime juice',
#   'cumin',
#   'coriander',
#   'cilantro',
#   'scallions',
#   'black beans',
#   'diced tomatoes',
#   'bell pepper',
#   'jalapeno chiles',
#   'salt and pepper'],
#  ['onion',
#   'garlic cloves',
#   'olive oil',
#   'chicken broth',
#   'frozen chopped spinach',
#   'couscous',
#   'parmesan cheese',
#   'lemon juice',
#   'salt',
#   'fresh ground pepper',
#   'pecans'],
#  ['fresh tortellini',
#   'tomatoes',
#   'frozen spinach',
#   'garlic cloves',
#   'feta cheese',
#   'cheese',
#   'sour cream',
#   'single cream',
#   'fresh ground black pepper',
#   'salt'],
#  ['water',
#   'yeast',
#   'sugar',
#   'salt',
#   'bread flour',
#   'egg white',
#   'cinnamon',
#   'raisins',
#   'poppy seed',
#   'dried onion',
#   'sesame seeds'],
#  ['chicken broth',
#   'chicken bouillon cube',
#   'rice',
#   'carrot',
#   'celery',
#   'onion',
#   'chicken',
#   'butter',
#   'flour',
#   'eggs',
#   'lemon juice',
#   'salt and pepper',
#   'lemon slice',
#   'green onions'],
#  ['chicken',
#   'lemon, juice of',
#   'dried oregano',
#   'salt',
#   'pepper',
#   'garlic cloves',
#   'potatoes',
#   'olive oil',
#   'water',
#   'minced garlic cloves'],
#  ['pie crust',
#   'sugar',
#   'flour',
#   'sour cream',
#   'egg',
#   'vanilla',
#   'salt',
#   'blueberries',
#   'butter',
#   'pecans'],
#  ['shrimp',
#   'mayonnaise',
#   'thai sweet chili sauce',
#   'hot chili sauce',
#   'cornstarch'],
#  ['jiffy corn muffin mix',
#   'eggs',
#   'butter',
#   'frozen corn',
#   'onion',
#   'small curd cottage cheese',
#   'sugar'],
#  ...]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# Create an object te by calling a method TransactionEncoder()
te = TransactionEncoder()

# Call fit() method to train the model
te_array = te.fit(ingredients).transform(ingredients)

# Transform te_array into dataframe
EncodedIngredients = pd.DataFrame(te_array, columns = te.columns_)

# %%
EncodedIngredients
# Out:
#        1% fat buttermilk  1% fat cottage cheese  1% low-fat milk  10% cream  \
# 0                  False                  False            False      False
# 1                  False                  False            False      False
# 2                  False                  False            False      False
# 3                  False                  False            False      False
# 4                  False                  False            False      False
# ...                  ...                    ...              ...        ...
# 39995              False                  False            False      False
# 39996              False                  False            False      False
# 39997              False                  False            False      False
# 39998              False                  False            False      False
# 39999              False                  False            False      False
#
#        10-inch  deep dish pie crust  10-inch baked pie shells  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False
# ...                             ...                       ...
# 39995                         False                     False
# 39996                         False                     False
# 39997                         False                     False
# 39998                         False                     False
# 39999                         False                     False
#
#        10-inch flour tortillas  10-inch pie shell  \
# 0                        False              False
# 1                        False              False
# 2                        False              False
# 3                        False              False
# 4                        False              False
# ...                        ...                ...
# 39995                    False              False
# 39996                    False              False
# 39997                    False              False
# 39998                    False              False
# 39999                    False              False
#
#        10-inch sun-dried tomato tortillas  10-minute herb stuffing mix  ...  \
# 0                                   False                        False  ...
# 1                                   False                        False  ...
# 2                                   False                        False  ...
# 3                                   False                        False  ...
# 4                                   False                        False  ...
# ...                                   ...                          ...  ...
# 39995                               False                        False  ...
# 39996                               False                        False  ...
# 39997                               False                        False  ...
# 39998                               False                        False  ...
# 39999                               False                        False  ...
#
#        yukon gold potato  yukon gold potatoes  za'atar spice mix  \
# 0                  False                False              False
# 1                  False                False              False
# 2                  False                False              False
# 3                  False                False              False
# 4                  False                False              False
# ...                  ...                  ...                ...
# 39995              False                False              False
# 39996              False                False              False
# 39997              False                False              False
# 39998              False                False              False
# 39999              False                False              False
#
#        zatarain's jambalaya mix  zinfandel  ziploc bag  ziploc bags  \
# 0                         False      False       False        False
# 1                         False      False       False        False
# 2                         False      False       False        False
# 3                         False      False       False        False
# 4                         False      False       False        False
# ...                         ...        ...         ...          ...
# 39995                     False      False       False        False
# 39996                     False      False       False        False
# 39997                     False      False       False        False
# 39998                     False      False       False        False
# 39999                     False      False       False        False
#
#        ziti pasta  zucchini  zucchini with italian-style tomato sauce
# 0           False     False                                     False
# 1           False     False                                     False
# 2           False     False                                     False
# 3           False     False                                     False
# 4           False     False                                     False
# ...           ...       ...                                       ...
# 39995       False     False                                     False
# 39996       False     False                                     False
# 39997       False     False                                     False
# 39998       False      True                                     False
# 39999       False     False                                     False
#
# [40000 rows x 8010 columns]

# %%
from mlxtend.frequent_patterns import apriori

# Calculate the sfrequenct itemsets by calling a method apriori
frequent_itemsets_ap = apriori(EncodedIngredients, min_support = 0.005, use_colnames = True)

# %%
frequent_itemsets_ap.sort_values(by = 'support', ascending = False)
# Out:
#        support                                        itemsets
# 211   0.401475                                          (salt)
# 35    0.259425                                        (butter)
# 232   0.203850                                         (sugar)
# 177   0.172725                                         (onion)
# 252   0.157650                                         (water)
# ...        ...                                             ...
# 1341  0.005000                        (salt, flour, margarine)
# 405   0.005000                                (butter, carrot)
# 1755  0.005000  (sugar, baking powder, flour, butter, vanilla)
# 352   0.005000                                (oregano, basil)
# 1270  0.005000                     (water, salt, chili powder)
#
# [1806 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

# Display the reles due to apriori algorithm
rules_ap = association_rules(frequent_itemsets_ap, metric = "confidence", min_threshold = 0.4)

print(rules_ap)
# Out:
#                           antecedents          consequents  \
# 0                  (active dry yeast)               (salt)
# 1                  (active dry yeast)              (sugar)
# 2                 (all-purpose flour)             (butter)
# 3                  (granulated sugar)  (all-purpose flour)
# 4                 (all-purpose flour)               (salt)
# ...                               ...                  ...
# 2359    (butter, vanilla, salt, eggs)       (sugar, flour)
# 2360  (butter, vanilla, sugar, flour)         (eggs, salt)
# 2361    (vanilla, eggs, sugar, flour)       (butter, salt)
# 2362   (butter, vanilla, eggs, sugar)        (salt, flour)
# 2363   (butter, vanilla, eggs, flour)        (salt, sugar)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 0               0.009150            0.401475  0.008225    0.898907  2.239011
# 1               0.009150            0.203850  0.005050    0.551913  2.707445
# 2               0.082075            0.259425  0.035575    0.433445  1.670791
# 3               0.027700            0.082075  0.011375    0.410650  5.003348
# 4               0.082075            0.401475  0.059125    0.720378  1.794328
# ...                  ...                 ...       ...         ...       ...
# 2359            0.011950            0.056000  0.005475    0.458159  8.181411
# 2360            0.011100            0.083025  0.005475    0.493243  5.940900
# 2361            0.011950            0.127250  0.005475    0.458159  3.600464
# 2362            0.012300            0.084275  0.005475    0.445122  5.281779
# 2363            0.009700            0.114250  0.005475    0.564433  4.940333
#
#       leverage  conviction  zhangs_metric
# 0     0.004552    5.920545       0.558484
# 1     0.003185    1.776774       0.636472
# 2     0.014283    1.307155       0.437379
# 3     0.009102    1.557521       0.822929
# 4     0.026174    2.140477       0.482271
# ...        ...         ...            ...
# 2359  0.004806    1.742208       0.888388
# 2360  0.004553    1.809497       0.841011
# 2361  0.003954    1.610712       0.730993
# 2362  0.004438    1.650318       0.820765
# 2363  0.004367    2.033556       0.805397
#
# [2364 rows x 10 columns]

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
# Evaluate the frequent item rules for fpgrowth function
frequent_itemsets_fp1 = fpgrowth(EncodedIngredients, min_support = 0.005, use_colnames = True)

print(frequent_itemsets_fp1)
# Out:
#        support                            itemsets
# 0     0.401475                              (salt)
# 1     0.259425                            (butter)
# 2     0.149300                              (eggs)
# 3     0.082075                 (all-purpose flour)
# 4     0.071925                       (baking soda)
# ...        ...                                 ...
# 1801  0.010275           (salt, whole wheat flour)
# 1802  0.006450    (baking soda, whole wheat flour)
# 1803  0.006025  (baking powder, whole wheat flour)
# 1804  0.006400                (salt, curry powder)
# 1805  0.005100               (curry powder, onion)
#
# [1806 rows x 2 columns]

# %%
# Display the reles due to fp-growth algorithm
rules_fp1 = association_rules(frequent_itemsets_fp1, metric = "confidence", min_threshold = 0.5)

print(rules_fp1)
# Out:
#                 antecedents     consequents  antecedent support  \
# 0                    (eggs)          (salt)            0.149300
# 1            (butter, eggs)          (salt)            0.064175
# 2             (eggs, sugar)          (salt)            0.059050
# 3             (eggs, sugar)        (butter)            0.059050
# 4     (butter, eggs, sugar)          (salt)            0.031125
# ...                     ...             ...                 ...
# 1440           (canola oil)          (salt)            0.017750
# 1441     (ground coriander)  (ground cumin)            0.008950
# 1442     (ground coriander)          (salt)            0.008950
# 1443    (whole wheat flour)          (salt)            0.013050
# 1444         (curry powder)          (salt)            0.012700
#
#       consequent support   support  confidence       lift  leverage  \
# 0               0.401475  0.083025    0.556095   1.385130  0.023085
# 1               0.401475  0.037625    0.586287   1.460334  0.011860
# 2               0.401475  0.039475    0.668501   1.665113  0.015768
# 3               0.259425  0.031125    0.527096   2.031784  0.015806
# 4               0.401475  0.020400    0.655422   1.632534  0.007904
# ...                  ...       ...         ...        ...       ...
# 1440            0.401475  0.009850    0.554930   1.382227  0.002724
# 1441            0.027200  0.005400    0.603352  22.182057  0.005157
# 1442            0.401475  0.005325    0.594972   1.481965  0.001732
# 1443            0.401475  0.010275    0.787356   1.961159  0.005036
# 1444            0.401475  0.006400    0.503937   1.255214  0.001301
#
#       conviction  zhangs_metric
# 0       1.348318       0.326844
# 1       1.446717       0.336842
# 2       1.805512       0.424507
# 3       1.566014       0.539691
# 4       1.736978       0.399902
# ...          ...            ...
# 1440    1.344787       0.281527
# 1441    2.452552       0.963542
# 1442    1.477738       0.328157
# 1443    2.814685       0.496578
# 1444    1.206550       0.205938
#
# [1445 rows x 10 columns]

# %% [markdown]
# # Building a Dashboard to visualise the data

# %%
df_recipes.head()
# Out:
#     index                                               name  recipe_id  \
# 0   22168                                  best banana bread       2886
# 1  213826                         to die for crock pot roast      27208
# 2   66687  crock pot chicken with black beans   cream cheese      89204
# 3   62431                         creamy cajun chicken pasta      39087
# 4   22388   best ever banana cake with cream cheese frosting      67256
#
#    minutes  contributor_id                                               tags  \
# 0       65            1762  [time-to-make, course, main-ingredient, cuisin...
# 1      545           28201  [weeknight, time-to-make, course, main-ingredi...
# 2      243          137839  [time-to-make, course, main-ingredient, prepar...
# 3       25           30534  [30-minutes-or-less, time-to-make, course, mai...
# 4       75           82367  [weeknight, time-to-make, course, main-ingredi...
#
#                                       nutrition  n_steps  \
# 0    [272.8, 16.0, 97.0, 14.0, 7.0, 31.0, 14.0]       13
# 1     [295.2, 14.0, 0.0, 15.0, 99.0, 19.0, 0.0]        7
# 2   [679.2, 53.0, 39.0, 38.0, 91.0, 75.0, 16.0]        5
# 3  [719.1, 63.0, 12.0, 34.0, 78.0, 120.0, 15.0]        4
# 4  [503.5, 31.0, 222.0, 15.0, 11.0, 61.0, 25.0]       18
#
#                                                steps  \
# 0  ['remove odd pots and pans from oven', 'prehea...
# 1  ['place beef roast in crock pot', 'mix the dri...
# 2  ['take 4-5 frozen , yes , frozen , boneless ch...
# 3  ['place chicken and cajun seasoning in a bowl ...
# 4  ['preheat oven to 275f', 'grease and flour a 9...
#
#                                          description  \
# 0  you'll never need another banana bread recipe ...
# 1  amazing flavor, and so simple! no salt needed ...
# 2  i love this crock-pot chicken recipe for two r...
# 3  n'awlin's style of chicken with an updated alf...
# 4  this is one of (if not) the best banana cake i...
#
#                                          ingredients  n_ingredients    rating  \
# 0  [butter, granulated sugar, eggs, bananas, all-...              8  4.185989
# 1  [beef roast, brown gravy mix, dried italian sa...              5  4.288570
# 2  [boneless chicken breasts, black beans, corn, ...              5  4.220393
# 3  [boneless skinless chicken breast halves, ling...             12  4.541436
# 4  [bananas, lemon juice, flour, baking soda, sal...             13  4.329047
#
#    reviews_count                                               soup
# 0           1613  time-to-make course main-ingredient cuisine pr...
# 1           1601  weeknight time-to-make course main-ingredient ...
# 2           1579  time-to-make course main-ingredient preparatio...
# 3           1448  30-minutes-or-less time-to-make course main-in...
# 4           1322  weeknight time-to-make course main-ingredient ...

# %%
df_recipes['word_count_on_steps'] = df_recipes['steps'].apply(lambda x: len(str(x).split(" ")))

# %%
print(df_recipes['steps'][0])
# Out:
# ['remove odd pots and pans from oven', 'preheat oven to 350 / 180', 'cream together butter and sugar', 'add eggs and crushed bananas', 'combine well', 'sift together flour , soda and salt', 'add to creamed mixture', 'add vanilla', 'mix just until combined', 'do not overmix', 'pour into greased and floured loaf pan', 'bake at 350 / 180 for 55 minutes', 'keeps well , refrigerated']

# %%
df_recipes[['name','word_count_on_steps']]
# Out:
#                                                     name  word_count_on_steps
# 0                                      best banana bread                   64
# 1                             to die for crock pot roast                   59
# 2      crock pot chicken with black beans   cream cheese                   69
# 3                             creamy cajun chicken pasta                   68
# 4       best ever banana cake with cream cheese frosting                  182
# ...                                                  ...                  ...
# 39995  norwegian scrambled eggs with smoked salmon an...                   76
# 39996                             norwegian stuffed eggs                   46
# 39997  not a secret anymore   japanese steakhouse whi...                   69
# 39998                       not just another pasta salad                   62
# 39999               not your ordinary boston baked beans                   34
#
# [40000 rows x 2 columns]

# %%
def avg_word(sentence):
    words = sentence.split()
    return (sum(len(word) for word in words)/len(words))
df_recipes['avg_word'] = df_recipes['steps'].apply(lambda x: avg_word(x)) 
df_recipes[['name','avg_word']].head()
# Out:
#                                                 name  avg_word
# 0                                  best banana bread  4.984375
# 1                         to die for crock pot roast  4.322034
# 2  crock pot chicken with black beans   cream cheese  3.724638
# 3                         creamy cajun chicken pasta  4.352941
# 4   best ever banana cake with cream cheese frosting  4.302198

# %%
df_recipes.head()
# Out:
#    level_0   index                                               name  \
# 0        0   22168                                  best banana bread
# 1        1  213826                         to die for crock pot roast
# 2        2   66687  crock pot chicken with black beans   cream cheese
# 3        3   62431                         creamy cajun chicken pasta
# 4        4   22388   best ever banana cake with cream cheese frosting
#
#    recipe_id  minutes  contributor_id  \
# 0       2886       65            1762
# 1      27208      545           28201
# 2      89204      243          137839
# 3      39087       25           30534
# 4      67256       75           82367
#
#                                                 tags  \
# 0  [time-to-make, course, main-ingredient, cuisin...
# 1  [weeknight, time-to-make, course, main-ingredi...
# 2  [time-to-make, course, main-ingredient, prepar...
# 3  [30-minutes-or-less, time-to-make, course, mai...
# 4  [weeknight, time-to-make, course, main-ingredi...
#
#                                       nutrition  n_steps  \
# 0    [272.8, 16.0, 97.0, 14.0, 7.0, 31.0, 14.0]       13
# 1     [295.2, 14.0, 0.0, 15.0, 99.0, 19.0, 0.0]        7
# 2   [679.2, 53.0, 39.0, 38.0, 91.0, 75.0, 16.0]        5
# 3  [719.1, 63.0, 12.0, 34.0, 78.0, 120.0, 15.0]        4
# 4  [503.5, 31.0, 222.0, 15.0, 11.0, 61.0, 25.0]       18
#
#                                                steps  ... n_ingredients  \
# 0  ['remove odd pots and pans from oven', 'prehea...  ...             8
# 1  ['place beef roast in crock pot', 'mix the dri...  ...             5
# 2  ['take 4-5 frozen , yes , frozen , boneless ch...  ...             5
# 3  ['place chicken and cajun seasoning in a bowl ...  ...            12
# 4  ['preheat oven to 275f', 'grease and flour a 9...  ...            13
#
#      rating  reviews_count                                               soup  \
# 0  4.185989           1613  time-to-make course main-ingredient cuisine pr...
# 1  4.288570           1601  weeknight time-to-make course main-ingredient ...
# 2  4.220393           1579  time-to-make course main-ingredient preparatio...
# 3  4.541436           1448  30-minutes-or-less time-to-make course main-in...
# 4  4.329047           1322  weeknight time-to-make course main-ingredient ...
#
#    word_count  avg_word  word_count_per_step  word_count_on_steps  \
# 0          64  4.984375                   64                   64
# 1          59  4.322034                   59                   59
# 2          69  3.724638                   69                   69
# 3          68  4.352941                   68                   68
# 4         182  4.302198                  182                  182
#
#    words_per_step                                 ingredients_parsed
# 0        4.923077           butter granulated sugar egg banana flour
# 1        8.428571                             beef gravy salad ranch
# 2       13.800000             chicken breast bean salsa cream cheese
# 3       17.000000  chicken breast linguine cajun butter onion cre...
# 4       10.111111  banana lemon flour butter sugar egg buttermilk...
#
# [5 rows x 22 columns]

# %%
df_users.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
df.groupby[by='recipe_id']
